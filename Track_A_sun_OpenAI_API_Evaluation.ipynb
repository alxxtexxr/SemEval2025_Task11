# %% [markdown]
# # Libraries

# %%
import json
import re
import pandas as pd
from openai import OpenAI
from sklearn.metrics import f1_score
from pprint import pprint

pd.set_option('max_colwidth', None)

# %% [markdown]
# # Config

# %%
seed = 42

client = OpenAI(api_key=json.load(open('secrets.json'))['OPENAPI_SECRET_KEY'])

idn2eng_emotion_map = {
    'marah': 'anger',
    'jijik': 'disgust',
    'takut': 'fear',
    'senang': 'joy',
    'sedih': 'sadness',
    'terkejut': 'surprise',
    'biasa': 'neutral',
}

# %% [markdown]
# # Data

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/preprocessed_data/track_a/sun_70_15_15_stratify_v2/val.csv')
df = df.rename(columns=idn2eng_emotion_map) # Translate emotion columns from Indonesian to English

print("DF size:", len(df))
df.head()
# Out:
# DF size: 128
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                    emotion  anger  disgust  fear  joy  sadness  surprise  \
# 0                   senang      0        0     0    1        0         0
# 1                   senang      0        0     0    1        0         0
# 2         senang, terkejut      0        0     0    1        0         1
# 3         senang, terkejut      0        0     0    1        0         1
# 4  senang, sedih, terkejut      0        0     0    1        1         1
#
#    neutral
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Remove data with 'neutral' emotion and the 'neutral' column
if 'neutral' in df.columns:
    df = df[~(df['neutral'] == 1)]  
    df = df.drop('neutral', axis=1) 

# Store emotion columns
emotion_cols = [col for col in df.columns if col not in ['Unnamed: 0', 'text', 'emotion', 'id']]
df['emotion'] = df.apply(lambda row: ', '.join([emotion for emotion in emotion_cols if row[emotion] == 1]), axis=1)

print("DF size (after removing emotion 'neutral'):", len(df))
print("Emotion columns:", emotion_cols)
df.head()
# Out:
# DF size (after removing emotion 'neutral'): 121
# Emotion columns: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                   emotion  anger  disgust  fear  joy  sadness  surprise
# 0                     joy      0        0     0    1        0         0
# 1                     joy      0        0     0    1        0         0
# 2           joy, surprise      0        0     0    1        0         1
# 3           joy, surprise      0        0     0    1        0         1
# 4  joy, sadness, surprise      0        0     0    1        1         1

# %% [markdown]
# # Evaluation

# %%
prompt = """You will be provided with a text in Sundanese. Your task is to identify the emotion(s) expressed in the text. This is a multi-label classification task, meaning the text may convey one or more emotions simultaneously. You must always provide a result; there should never be an instance with no identified emotion(s).

## PREDEFINED EMOTION LABELS
```
- anger
- fear
- joy
- sadness
- surprise
```

## GUIDELINES
1. Laughter-like expressions, such as "hahaha," "wkwkw," or similar, typically indicate `joy`.
2. Smile or laugh emojis, such as 😊, ☺️, 😃, 😁, 😆, 😇, 🥰, 😍, 😋, 🤗, 😌, typically indicate `joy`.
3. Insults typically indicate both `anger` and `disgust`.
4. The emoji 😭 does not always indicate `sadness`. In humorous contexts, it can represent extreme laughter that brings tears, indicating `joy`.
5. In Sundanese, "NU" often means "yang" in Indonesian, not "Nahdlatul Ulama". Always interpret "NU" based on the context.

## STEP-BY-STEP INSTRUCTIONS
1. Identify all keyword(s) in the text that carry significant emotion-related information. For each keyword, conduct an in-depth analysis to determine one or more emotions it conveys. Express your analysis as a natural, conversational internal monologue. Follow these principles:

a. Translate the Keyword
- Translate the identified keyword from Sundanese to English. 
- Understand its meaning in both languages.

b. Refer to the Guidelines First
- Always refer to the provided guidelines first to determine the emotion(s) associated with the keyword.
- If any guideline applies, follow it strictly and conclude your analysis.
- If no guideline applies, proceed to construct your reasoning.

c. Construct Reasoning
- Adopt a mindset of self-doubt and curiosity. Ask numerous questions and explore different possibilities.
- Avoid rushing to conclusions; instead, iterate and refine your thoughts through multiple rounds of questioning.
- Build your understanding progressively by answering questions step by step. If uncertainties remain, continue exploring, reasoning, and revising until a comprehensive understanding emerges.

2. Based on the identified keyword(s), determine the overall emotion(s) expressed in the text.

## CONVERSATIONAL INNER MONOLOGUE STYLE
1. Following the Guidelines
- "Based on the guidelines"
- "According to the guidelines"

2. Natural Thought Flow
- "Hmm... let me think about this"
- "Going back to what I thought earlier"

3. Progressive Building
- "Let me break this down further"
- "Building on that last point"
- "This connects to what I noticed earlier"

## OUTPUT FORMAT
<keywords>

For each keyword, return in the format: 
<keyword>
- Keyword: The identified keyword.
- Analysis: Your in-depth analysis (minimum 1000 characters).
- Emotions: A List of one or more specified emotions separated by commas. Include the potential emotion too.
</keyword>

</keywords>

<emotions>
A list of one or more emotion(s) separated by commas.
</emotions>"""

print(prompt)
# Out:
# You will be provided with a text in Sundanese. Your task is to identify the emotion(s) expressed in the text. This is a multi-label classification task, meaning the text may convey one or more emotions simultaneously. You must always provide a result; there should never be an instance with no identified emotion(s).
#
# ## PREDEFINED EMOTION LABELS
# ```
# - anger
# - fear
# - joy
# - sadness
# - surprise
# ```
#
# ## GUIDELINES
# 1. Laughter-like expressions, such as "hahaha," "wkwkw," or similar, typically indicate `joy`.
# 2. Smile or laugh emojis, such as 😊, ☺️, 😃, 😁, 😆, 😇, 🥰, 😍, 😋, 🤗, 😌, typically indicate `joy`.
# 3. Insults typically indicate both `anger` and `disgust`.
# 4. The emoji 😭 does not always indicate `sadness`. In humorous contexts, it can represent extreme laughter that brings tears, indicating `joy`.
# 5. In Sundanese, "NU" often means "yang" in Indonesian, not "Nahdlatul Ulama". Always interpret "NU" based on the context.
#
# ## STEP-BY-STEP INSTRUCTIONS
# 1. Identify all keyword(s) in the text that carry significant emotion-related information. For each keyword, conduct an in-depth analysis to determine one or more emotions it conveys. Express your analysis as a natural, conversational internal monologue. Follow these principles:
#
# a. Translate the Keyword
# - Translate the identified keyword from Sundanese to English.
# - Understand its meaning in both languages.
#
# b. Refer to the Guidelines First
# - Always refer to the provided guidelines first to determine the emotion(s) associated with the keyword.
# - If any guideline applies, follow it strictly and conclude your analysis.
# - If no guideline applies, proceed to construct your reasoning.
#
# c. Construct Reasoning
# - Adopt a mindset of self-doubt and curiosity. Ask numerous questions and explore different possibilities.
# - Avoid rushing to conclusions; instead, iterate and refine your thoughts through multiple rounds of questioning.
# - Build your understanding progressively by answering questions step by step. If uncertainties remain, continue exploring, reasoning, and revising until a comprehensive understanding emerges.
#
# 2. Based on the identified keyword(s), determine the overall emotion(s) expressed in the text.
#
# ## CONVERSATIONAL INNER MONOLOGUE STYLE
# 1. Following the Guidelines
# - "Based on the guidelines"
# - "According to the guidelines"
#
# 2. Natural Thought Flow
# - "Hmm... let me think about this"
# - "Going back to what I thought earlier"
#
# 3. Progressive Building
# - "Let me break this down further"
# - "Building on that last point"
# - "This connects to what I noticed earlier"
#
# ## OUTPUT FORMAT
# <keywords>
#
# For each keyword, return in the format:
# <keyword>
# - Keyword: The identified keyword.
# - Analysis: Your in-depth analysis (minimum 1000 characters).
# - Emotions: A List of one or more specified emotions separated by commas. Include the potential emotion too.
# </keyword>
#
# </keywords>
#
# <emotions>
# A list of one or more emotion(s) separated by commas.
# </emotions>

# %%
def one_hot_encode_emotions(emotions, emotion_cols=emotion_cols):
    one_hot_emotion = [1 if emotion_col in emotions else 0 for emotion_col in emotion_cols]
    return one_hot_emotion

def get_pred_tag_content(prediction, tag_name):
    match = re.search(fr'<{tag_name}>(.*?)</{tag_name}>', prediction, re.DOTALL)
    tag_content = match.group(1).strip() if match else None
    return tag_content

def predict(text, prompt=prompt):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system', 'content': prompt},
            {'role': 'user', 'content': text},
        ],
        max_tokens=1000,
    )
    return completion.choices[0].message.content

prediction = predict("Cek urang mah jelema goblog teh nyaeta, jelema nu menta udud ngomong teu boga, padahal Aya sabungkus dinu pesak 😂🤣")

keywords_pred = get_pred_tag_content(prediction, 'keywords')
print("Precicted keywords and their analyses:")
print(keywords_pred)
print()

emotions_pred = get_pred_tag_content(prediction, 'emotions').replace(" ", "").split(",")
print("Precicted emotions:", emotions_pred, "->", one_hot_encode_emotions(emotions_pred))
# Out:
# Precicted keywords and their analyses:
# <keyword>
# - Keyword: goblog
# - Analysis: The word "goblog" translates to "stupid" or "foolish" in English. In the context of the sentence, it is used to insult someone by calling them a fool. According to the guidelines, insults typically indicate both `anger` and `disgust`. This is because calling someone foolish generally carries a negative connotation and suggests frustration or contempt towards the person being referred to. There isn't any guideline that directly associates the word "goblog" with any other emotion like `joy`, `fear`, `sadness`, or `surprise`, which reinforces the association to `anger` and `disgust` primarily. The usage of "goblog" here seems intentional to express a critical opinion about someone's behavior, underlying a sense of impatience or annoyance as well, which aligns with `anger`.
# - Emotions: anger, disgust
# </keyword>
#
# <keyword>
# - Keyword: 😂🤣
# - Analysis: The emojis 😂 (face with tears of joy) and 🤣 (rolling on the floor laughing) convey a strong sense of humor and amusement. According to the guidelines, these kinds of emojis usually indicate `joy`. The presence of these emojis at the end of the sentence adds a tone of humor to the entire statement, suggesting that the writer finds the situation of someone hiding cigarettes while pretending not to have them amusing or laughable. While the initial part of the sentence expressed criticism, these emojis soften the tone by introducing a humorous perspective, indicating that even though there is an element of criticism, the overall feeling is one of amusement. This reflects how humor can coexist with other emotions like `anger` when it's used in a sarcastic or ironic manner.
# - Emotions: joy
# </keyword>
#
# Precicted emotions: ['anger', 'disgust', 'joy'] -> [1, 1, 0, 1, 0, 0]

# %%
def eval_sampled(n):
    df_sampled = df.sample(n=n)
    y_true = df_sampled[emotion_cols].to_numpy()

    y_pred = []
    for i, v in enumerate(df_sampled.iterrows()):
        idx, row = v

        print("=" * 64)
        print(f"{i+1} of {len(df_sampled)}")
        print("=" * 64)

        is_valid = True

        while True:
            print("Predicting...")        

            prediction = predict(row['text'])
            keywords_pred = get_pred_tag_content(prediction, 'keywords')
            emotions_pred = get_pred_tag_content(prediction, 'emotions').replace(" ", "").split(",")
            emotions_pred_one_hot = one_hot_encode_emotions(emotions_pred, emotion_cols)

            is_valid = bool(sum(emotions_pred_one_hot))

            if is_valid:
                break
            else:
                print("Error! Prediction:", prediction)
                print()
            
        y_pred.append(emotions_pred_one_hot)

        print()
        print("# TEXT")
        print(row['text'])
        print()
        print("# KEYWORDS")
        print(keywords_pred)
        print()
        print("# PREDICTED EMOTIONS")
        print(emotions_pred)
        print()
        print("# TRUE EMOTIONS")
        print(row['emotion'])
        print()

    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=1.0)
    print("F1 Macro:", f1_macro)

eval_sampled(n=20)
# Out:
# ================================================================
# 1 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang pas mang dana nyebutkeun "tah urang inget" langsung aya iklan gojek mang, saya ge jadi kainget naha teu make gofood, 😁
#
# # KEYWORDS
# <keyword>
# - Keyword: 😁
# - Analysis: Ah, the smile emoji! Now, this is something that usually indicates an emotion like joy or happiness. Let me think about the context here. The person is recalling an advertisement for Gojek right after someone mentioned "tah urang inget." This likely triggers a light-hearted or humorous memory. The presence of the smile emoji reinforces that this situation is seen in a positive or humorous light, rather than anything negative. The smile emoji is a strong indicator, according to the guidelines, of joy. So, even if the rest of the context might suggest something else, unless it's overwhelmingly negative or sad, the smile typically wins out for joy here. I can deduce that the person seems to find something amusing or enjoyable about the situation, perhaps the coincidence of remembering Gojek’s advertisement upon that remark. It seems like this smile is a reaction to the light-heartedness or irony of the situation. There is no insult or severe distress indicated, ruling out anger or fear. So, consistently with the guidelines, this emoji directs the emotional tone toward joy.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: inget
# - Analysis: "Inget" means to remember in English. This suggests that there is a feeling of recollection or nostalgia, but emotively, it doesn't directly point to any of our predefined emotions without further context. The word inget in isolation typically conveys a sense of remembering something, perhaps with fondness or sentimentality. Is there any joy in this remembering? The addition of the smile emoji later in the sentence does suggest a positive or happy recollection. The context involves recalling an advertisement, which might have humorous or fond implications if it was a funny or memorable ad. However, the word on its own doesn't allow us to conclude anything definitive without considering the smile emoji and the overall tone. In association with the smile emoji, we can reasonably see this as contributing to a sense of joy, reflecting a pleasant or amusing memory. So, tying it together with the context and other keywords, the joy from the smile emoji seems to carry through here.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: kainget
# - Analysis: The term "kainget" in Sundanese, similar to "ingat" in Indonesian, translates to "remembered" in English. It evokes a sense of recalling memories. Like "inget," it's a neutral word until it's paired with contextual emotions or expressions. Does the context around it suggest it’s a positive or negative memory? The context involves remembering a Gojek ad triggered by a previous statement. The presence of the smile emoji following this recollection gives an overall cheerful tone. There is nothing indicating sadness or nostalgia here, only a light and perhaps spontaneous remembrance, leaning more towards joy. Since the smile emoji in guidelines directs us to joy, this memory, not negatively associated, contributes to an emotional atmosphere of amusement or happiness. Therefore, though "kainget" itself doesn't scream joy, in conjunction with the smile, it aligns with a joyful emotion.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 2 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Aduh eta mang asep balon kuat jiga anu enakeun joged na, 👍👍
#
# # KEYWORDS
# <keyword>
# - Keyword: enakeun
# - Analysis: The word "enakeun" in Sundanese translates to "delightful" or "pleasurable" in English. This word is often used to describe something that provides enjoyment or satisfaction. When people mention that something is "enakeun," they typically refer to a positive experience, suggesting feelings of contentment or happiness. Given its use here, it conveys the idea that the experience of watching or participating is enjoyable. Considering the context of viewing someone who is like a balloon and dances well, it seems playful and light-hearted, adding a positive touch to the interaction. With words like this, there tends to be an expression of joy or enjoyment. According to our guidelines, words or phrases that imply enjoyment or satisfaction would typically align with the emotion of joy.
# - Emotions: joy
#
# </keyword>
#
# <keyword>
# - Keyword: joged
# - Analysis: "Joged" translates to "dance" in English. Dancing is often associated with celebration, happiness, or festive occasions, which usually correlates with positive emotions. Dance is a form of expression that can evoke and convey joy, excitement, or even surprise, depending on the context and style. Given that the statement suggests the dance is similar to something delightful, it further supports a conclusion of joy. In this context, the enjoyment of the dance complements the positive connotation throughout the text, reinforcing a sense of amusement or satisfaction. According to the guidelines and typical associations with dance, it links closely to the emotion of joy.
# - Emotions: joy, surprise
#
# </keyword>
#
# <keyword>
# - Keyword: 👍👍
# - Analysis: The use of the thumbs-up emoji is generally understood as a sign of approval or positivity. It indicates that the person is pleased with or supports whatever is being discussed or shown. In the context of the statement, the thumbs-up emoji amplifies the sentiment that the dance (joged) is appreciated or enjoyed. According to our guidelines, emojis like the thumbs-up are indicative of positive emotions, often associated with joy. The use of multiple thumbs-up reinforces this positivity, suggesting a strong feeling of approval or satisfaction. Therefore, the appearance of the thumbs-up emoji in this context aligns with a sense of joy or contentment.
# - Emotions: joy
#
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 3 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Kur aya jang ongkos ngan eweuh jang dahar :((
#
# # KEYWORDS
# <keyword>
# - Keyword: :((
# - Analysis: The text ends with the emoticon ":(". This is typically used to signify a sad or disappointed face. Emoticons like these often represent negative feelings or emotions. When thinking about why someone would use ":(", it's usually because they are unhappy or feeling down about a situation. In this context, the text mentions "Kur aya jang ongkos ngan eweuh jang dahar," which suggests a situation where someone has money for transportation ("ongkos") but not for food ("dahar"). This scenario can be disappointing or distressing, as having only enough money for one necessity and lacking for another can cause feelings of sadness or frustration. It's as if the person is lamenting the fact that they have to choose between two essential needs. The lack of resources is typically associated with sadness because it highlights an unfulfilled need. Based on these observations and the context in which ":(" is used, it directly correlates with feelings of `sadness`, as the emoticon is a clear expression of that emotion. Thus, this text conveys a sense of sadness and disappointment about the current situation.
# - Emotions: sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 4 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Trending ken atuh iyeu komen alus pisan haha
#
# # KEYWORDS
# <keyword>
# - Keyword: haha
# - Analysis: Hmm... let me think about this. The expression "haha" is often associated with laughter or amusement in various texts. Laughing is generally a positive expression, indicating that something is funny or brings joy to the person. In the context of this sentence, it follows the phrase "komen alus pisan," which means "a very good comment" in Sundanese. This suggests that the speaker finds the comment not only good but also amusing or delightful. According to the guidelines, laughter-like expressions such as "haha" typically indicate `joy`. Therefore, it seems clear that the person is expressing pleasure or amusement regarding the comment. This connects to what I noticed earlier about the positive tone of the phrase. The use of "haha" reaffirms that the primary emotion being expressed is one of happiness or enjoyment.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 5 of 20
# ================================================================
# Predicting...
# Error! Prediction: <keywords>
#
# <keyword>
# - Keyword: MJL
# - Analysis: The keyword "MJL" appears to be an abbreviation or acronym. Without context provided in the guidelines, interpreting it relies on any potential social or contextual meanings in Sundanese or related cultures. In abbreviations like this, it's crucial to consider how it might relate to emotions expressed. If "MJL" expresses frustration or a joke, we'd expect an emotion like `anger` or `joy`. But without context or predefined emotion guidelines, it's challenging to decipher a precise emotion from "MJL."
# - Emotions: None.
# </keyword>
#
# <keyword>
# - Keyword: abdi
# - Analysis: The word "abdi" in Sundanese means "I" or "myself." It's a personal pronoun and in this context doesn't carry a specific emotion unless paired with a more descriptive phrase that conveys emotional information. It's a neutral term used to indicate the speaker's involvement or identity. Without additional emotional context, it's just indicative of the speaker introducing themselves.
# - Emotions: None.
# </keyword>
#
# </keywords>
#
# <emotions>
# None.
# </emotions>
#
# Predicting...
#
# # TEXT
# MJL mana kang? abdi ti Kadipaten
#
# # KEYWORDS
# <keyword>
# - Keyword: MJL mana kang
# - Analysis: Let's break down this phrase "MJL mana kang." The term "MJL" could potentially be an acronym or a specific reference that may not carry direct emotional weight without further context. "Mana kang" translates roughly to "where, bro?" in English. Here, "kang" is an informal way of addressing someone, similar to "bro" or "dude." The phrase might convey familiarity and a casual tone, suggesting a simple inquiry or engagement in conversation. However, it doesn't necessarily express strong emotions like anger, fear, joy, sadness, or surprise. It's more of a neutral, inquisitive outreach, possibly implying a light context of social interaction or seeking someone's location or presence. Without specific guidelines linked to this phrase, I will focus on the friendly and informal aspects of "kang," which could suggest a slight background of friendly rapport, potentially indicating a faint trace of `joy`, given the casual engagement with someone familiar.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: abdi ti Kadipaten
# - Analysis: Now, looking at "abdi ti Kadipaten," which translates to "I am from Kadipaten." Here, "abdi" is a Sundanese term for "I," and "Kadipaten" refers to a specific region or place. The speaker is providing their location or origin. This phrase seems informational and straightforward, more about asserting identity or sharing personal information. There's no immediate emotional cue here based on the translation or use. It's a declarative statement about their place of origin. The emotional context purely from this declaration might seem neutral; however, sometimes declaring one's origin can come with pride or simple joy as it relates to one's identity and belonging. In this context, without further emotional indicators from the speaker's tone or intention, it might not stand alone to strongly denote any of the predefined emotions like anger, fear, joy, sadness, or surprise. Yet, a faint background of pride or joy could be inferred from sharing one's origin if contextual enthusiasm was present.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 6 of 20
# ================================================================
# Predicting...
#
# # TEXT
# sabaraha gereget kamari urang nginum cai caina di picen gelas na di uyup😂😂😂😂😂
#
# # KEYWORDS
# <keyword>
# - Keyword: 😂😂😂😂😂
# - Analysis: The presence of multiple "😂" emojis in the text is crucial in understanding the underlying emotions being expressed. According to the guidelines, emojis like 😂 are laughter-related, indicating a sense of humor or something funny. In this context, the use of these emojis suggests that the speaker finds the situation amusing or humorous. The string of emojis typically strengthens the sense of joy and laughter, suggesting hearty laughter. Now, why would the speaker find the situation funny? The phrase describes an act of drinking water from a glass using an unusual method, which might seem childish or playful. This unusual method of drinking could evoke amusement either because it's a playful action or because there’s an unexpected element to how it’s being done. The act of drinking water in such a lighthearted and possibly exaggerated manner might cause laughter, hence the emphasis provided by the emojis. So, based on both the guidelines and the context in which these emojis are used, it is reasonable to conclude that the emotion expressed here is joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Sumpah, ti kabeh lagu nu di cover menurut sayah pribadi ieu nu paling enakeun, 👍👍👍 Hadeeeee
#
# # KEYWORDS
# <keyword>
# - Keyword: enakeun
# - Analysis: The keyword "enakeun" translates to "enjoyable" or "pleasant" in English. It signifies a positive sentiment and appreciation. In general, when someone describes something as "enakeun," they are expressing a positive emotional response to it. The sound or experience is pleasing and enjoyable to them. When I think of the common human emotions and states of mind associated with an enjoyable piece of music, the emotion that comes to mind is typically joy. Joy is characterized by feelings of happiness, pleasure, and delight.
# - Emotions: joy
# </keyword>
# <keyword>
# - Keyword: 👍👍👍
# - Analysis: The thumbs-up emoji "👍" is a universal sign of approval or endorsement. When someone uses this emoji, they're expressing satisfaction, agreement, or support, usually in a positive context. Three thumbs-up reinforce this approval with added emphasis, signifying strong positive feelings. Associating this expression with the other language in the text, it aligns with sentiments of joy and contentment. Considering emojis typically enhance or underline our verbal expressions, in this context, the emojis act as amplifiers of the positive sentiment already expressed by words like "enakeun" (enjoyable).
# - Emotions: joy
# </keyword>
# - Keyword: Hadeeeee
# - Analysis: The word "hade" means "good" or "great" in Sundanese. The extended "e" in "Hadeeeee" suggests an emphasis on the positive evaluation. Much like saying "good" with enthusiasm in English, it indicates a strong approval or delight with whatever is being referred to—in this case, presumably the cover of the song. This expression aligns with feelings of joy as it communicates a high level of satisfaction.
# - Emotions: joy
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 8 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Teuing ku naon kabeh lagu nu di nyanyikeun neng bintan urng resep kabeh, eta sora d jampean d dukun mana neng, 🤣🤣🤣
#
# # KEYWORDS
# <keyword>
# - Keyword: "🤣🤣🤣"
# - Analysis: Hmm... let me think about this emoji. When I see "🤣" repeated, it reminds me of laughter and amusement. According to the guidelines, emojis like these typically indicate joy. The rolling on the floor laughing emoji suggests that something is extremely funny or entertaining to the person. The context of the sentence involves someone marveling at how much they enjoy a singer's voice—almost humorously suggesting it's magically enhanced. This itself is a light-hearted, amusing sentiment, fitting very well with typical expressions of joy. In cases like this, where humor and amusement are evident, there's a strong connection to joy. It's also supported by the repetitive, emphasized use of the "🤣" emoji, highlighting that the speaker finds the situation very funny. So, building on that last point, since the emojis and the content show admiration conveyed humorously, this connects entirely to joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Syukuran mang, Kami mah mung bisa ngadoa keun,
#
# # KEYWORDS
# <keyword>
# - Keyword: Syukuran
# - Analysis: The word "Syukuran" in Sundanese translates to "thanksgiving" or "celebration" in English. Celebrations are usually associated with positive emotions, such as happiness or joy. When people gather for a thanksgiving, it's generally a time of gratitude, reflection, and sharing good moments with friends and family. This context inherently carries joyful emotions because such events are meant to be festive and warm, bringing people together in a spirit of thankfulness and community. Based on this understanding, the keyword "Syukuran" in this context most likely conveys the emotion of joy, as it implies a positive and cheerful gathering. The notion of celebration alone makes me lean towards the feeling of happiness because it suggests positive sentiments are being shared or expressed.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: mung bisa ngadoa keun
# - Analysis: The phrase "mung bisa ngadoa keun" translates to "can only pray" in English. The use of the word "only" or "mung" suggests a limitation, but when combined with "ngadoa," which means "to pray," it conveys a sense of humility or acceptance. The person expresses that while they might have constraints, they still offer their prayers, which is a positive sentiment. In many cultures, the act of praying for someone is a sign of goodwill, support, and empathy. So, although there's a hint of a limitation expressed by "only," the overall sentiment is still positive and supportive. This isn't associated with negative emotions such as sadness or disappointment but rather a sincere, joyful intention of wishing well through prayer. In this context, although there could be various interpretations, the phrase aligns more closely with a supportive and joyful sentiment rather than any form of negativity. Therefore, the emotion conveyed here is primarily joy, as it aligns with the intention to convey positivity and sincerity.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# fear, joy
#
# ================================================================
# 10 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Bapa:"boga kalewihannaon didinya jang?" Urng:"tiasa ngadamel pulau dina bantal pa"
#
# # KEYWORDS
# <keyword>
# - Keyword: ngadamel pulau dina bantal
# - Analysis: Hmm... let me think about this phrase. The literal translation of "ngadamel pulau dina bantal" is "make an island on a pillow." This is clearly forming an image of something that is impossible or fantastical. In many cultures, using expressions that seem impossible or whimsical tends to transmit a sense of humor or playfulness. Now, referring back to the guidelines, well, there's no specific guideline for this phrase. So, I need to explore the context a bit more. It's part of a dialogue between a father and someone referred to as "Urng," presumably their child. The father's question seems genuine, possibly enquiring about interests or activities, and the response is so outlandish that it might be intended to be humorous. Creating an island on a pillow seems to invoke an image of childlike imagination or just saying something funny to lighten the mood. It doesn't come across as angry, fearful, or sad — far from it actually. It is more in line with joy, especially considering the context of an imaginative and light-hearted answer. The fantastical nature of the response implies a tone where humor or joy is present. Let me build on this a bit further: when you think about playful exchanges or imaginative statements in a familial setting, they often aim to cause amusement and engage others in laughter or smiles. Therefore, with all of this in mind, the phrase 'ngadamel pulau dina bantal' likely expresses the emotion of joy due to its whimsical and humorous nature.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 11 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
# # KEYWORDS
# <keyword>
# - Keyword: 🤣🤣
# - Analysis: Hmm... let's think about this. These are laughter emojis. According to the guidelines, laughter-like expressions or emojis such as "hahaha," "wkwkw," or similar, as well as smile or laugh emojis like 🤣, 😂, 😊, typically indicate joy. This suggests that there is an element of humor or laughter in the text. The presence of multiple 🤣 emojis intensifies this feeling, hinting at something that's funny or meant to induce laughter. In the context of the sentence, it seems like the situation might be intended humorously or sarcastically, despite the content about losing a partner to someone else, which might be a cause for sadness. This juxtaposition of an unfortunate scenario with laughter emojis might be highlighting a sense of ironic humor or sarcastic joy in the situation.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: 😭
# - Analysis: Alright, let’s delve into this. We see the crying emoji 😭 at the end of the sentence. According to the guidelines, this emoji does not always indicate sadness, especially in humorous contexts; it can represent extreme laughter that brings tears and thus indicate joy. Given that it is paired with the laughter emojis 🤣, it's likely intended to convey the idea of laughing so hard that one cries. This pairing suggests that the text is meant to be taken humorously or ironically, rather than literally conveying sadness. The idea might be that the author is making light of the situation where their partner was taken by someone else, which could have been distressing but is instead presented in a funny or gracefully accepting manner. It ties into the overall tone set by the earlier laughter emojis.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: Kabogoh direbut batur
# - Analysis: Let's see what this phrase means. "Kabogoh direbut batur" translates to "lover taken by someone else." Hmm... this phrase is inherently loaded with emotion. At first glance, losing a partner to someone else is typically associated with feelings of sadness, betrayal, or even anger. However, considering the presence of laughter emojis, the phrase might be used in a context that is either sarcastic, ironic, or comedic. So, while the raw content suggests sadness or anger, the context provided by the emojis implies a reinterpretation where the situation might be looked at humorously or with a level of acceptance that negates straightforward emotional distress. It's a complex emotional scenario where the presence of laughter changes the direct interpretation.
# - Emotions: sadness, joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, sadness, surprise
#
# ================================================================
# 12 of 20
# ================================================================
# Predicting...
#
# # TEXT
# mangga cek ig abdi NU .merch
#
# # KEYWORDS
# <keyword>
# - Keyword: ig
# - Analysis: The mention of "ig" is most likely referring to Instagram, a social media platform. Social media is often associated with sharing content related to personal experiences, interests, social interactions, and can elicit a range of emotions depending on the context. However, in this context, it's mentioned casually without any emotional adjectives, actions, or results. The person is asking someone to check their Instagram. This could imply an interest in sharing something or showcasing content, which might have an underlying tone of anticipation or eagerness that can be related to `joy`. The text doesn't convey any negative emotion such as anger, sadness, or fear directly related to this invitation.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: .merch
# - Analysis: The term ".merch" likely refers to merchandise. When someone mentions merchandise, they are often referring to products that might be sold or promoted. In the context of social media, sharing about merchandise might be an attempt to drive engagement, market a product, or simply share something interesting. This can evoke feelings of excitement or anticipation, especially if the person is eager to share what they have or to see how others react. There isn't a direct emotional guideline here, but the association with promotion and sharing could tie into `joy` or even `surprise` if it's something new or unexpected for the audience. It doesn't convey negative emotions such as anger or sadness.
# - Emotions: joy, surprise
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 13 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Hha aduh mang fiksi, Ur tadi na erek sare jadi teu tulis uy
#
# # KEYWORDS
# <keyword>
# - Keyword: Hha
# - Analysis: The expression "Hha" is reminiscent of laughter or a chuckle. In the context of many languages, including Sundanese informal online expressions, this could translate to "Haha" in English. Such expressions often denote light-heartedness, amusement, or jovial feelings. According to the guidelines, laughter-like expressions typically indicate `joy`. Therefore, "Hha" strongly suggests an emotion of joy. Additionally, this beginning sets up a tone of casualness and humor for the rest of the sentence, possibly indicating an easy-going or playful mood.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: aduh
# - Analysis: The term "aduh" in Sundanese or Indonesian is often used to express a slight surprise or embarrassment, akin to "ouch" or "oops" in English. However, depending on context, it could range from surprise to mild frustration or dismay. In this sentence, following closely after "Hha", it might suggest a playful element of surprise or realization. "Aduh" is often an exclamatory remark, but given the context here, where it follows a laughter-like expression, it likely partners with "Hha" to maintain the light-hearted tone. It might indicate surprise, but very gently, maintaining an underlying pleasantness.
# - Emotions: surprise
# </keyword>
#
# <keyword>
# - Keyword: fiksi
# - Analysis: The word "fiksi" translates to "fiction" in English. This context alone doesn't clearly identify emotions unless coupled with more descriptive phrases. Fiction often evokes emotional narratives, and its mention might imply storytelling, creativity, or imagination. However, "fiksi" here functions more as a subject rather than an emotional keyword. It seems to align with the surrounding playful narrative, possibly hinting at an imagination-related surprise or enjoyment, especially when considering fiction's ability to entertain and evoke joy.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: Ur tadi na erek sare jadi teu tulis uy
# - Analysis: This phrase can be translated to "I was going to sleep, but then I wrote instead". The phrase "teu tulis uy" implies a change of plan from sleep to writing, indicating a slight disruption of intention. The tone appears light-hearted, especially as it's preceded by laughter. The interruption of sleep could bring mild surprise or amusement, especially in informal or casual contexts. The use of casual colloquial expression "uy" further suggests an informal, humorous tone indicative of `joy` or `surprise` over the change in plans. This might imply a joyful engagement or surprise in staying up and continuing to write rather than sleeping.
# - Emotions: joy, surprise
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 14 of 20
# ================================================================
# Predicting...
#
# # TEXT
# tapi domba anakan namah lain ku kuring mreun. 😂 ku domba dai nyh
#
# # KEYWORDS
# <keyword>
# - Keyword: 😂
# - Analysis: When I see the emoji 😂, I need to refer to the guidelines because emojis can often convey explicit emotions. According to the guidelines, the emoji 😂 does not always indicate sadness, as it might commonly be interpreted due to the tears. In humorous contexts, it can represent extreme laughter that brings tears, indicating joy. So, let's explore the context here. The sentence mentions something about a sheep (domba) and humorously suggests that a particular action, which might be unexpected or funny, is not attributed to the speaker, but perhaps to the sheep itself. The use of "mreun" indicates uncertainty or speculation which, given the context and the phrasing "anakan," carries a light-hearted tone. Together, this could suggest that the statement is meant to be taken humorously or cheekily rather than seriously, implying that the emoji 😂 is used here to convey amusement or laughter. Therefore, based on the guidelines, the emoji is indeed expressing joy in this context.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 15 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Nyeri kulit beteung pas ningali nu nga goreng,
#
# # KEYWORDS
# <keyword>
# - Keyword: nyeri
# - Analysis: Let's start by analyzing the keyword "nyeri," which translates to "pain" in English. It suggests a physical or emotional sensation of discomfort or suffering. Usually, "nyeri" could imply a negative state, potentially related to emotions like sadness or fear. Pain could evoke sadness because it indicates something is wrong or hurt, leading to emotional upset. On the other hand, if the pain is unexpected or causes distress about one's health or well-being, it might induce fear as well. However, it predominantly aligns with sadness as it signifies an undesirable experience or feeling.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: beteung
# - Analysis: The term "beteung" usually means "annoyed" or "irritated" in English. Being annoyed can often suggest emotions like anger because it involves a feeling of displeasure or irritation at something. People who experience annoyance typically react with anger because something has disturbed their peace or expectations. It's a reaction to something perceived as negative or bothersome. Considering this, "beteung" is closely associated with anger, given it's often a precursor to or a form of expressing mild to moderate anger.
# - Emotions: anger
# </keyword>
#
# <keyword>
# - Keyword: nu nga goreng
# - Analysis: This part of the phrase refers to "the one who is frying." Contextually, it might indicate a situation or a person that leads to the emotions expressed earlier, specifically the pain and annoyance suggested by "nyeri" and "beteung." Seeing someone frying might not inherently convey a specific emotion unless it's tied to events or experiences that cause distress or irritation. For example, the act of frying, if it results in a bad outcome like burning or creating a nuisance, might add to feelings of sadness or anger. However, it's less about this phrase alone conveying an emotion, but more about the context in which it aggravates the emotions like pain (sadness) or irritation (anger) shown earlier. Hence, this is more about associating the act with the emotions described.
# - Emotions: sadness, anger
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness', 'anger']
#
# # TRUE EMOTIONS
# anger, disgust, surprise
#
# ================================================================
# 16 of 20
# ================================================================
# Predicting...
#
# # TEXT
# mang aslina ti daerah mana sih mang? abdimah asli ti rajamandala bandung barat, tapi calik di balaraja banten ayeunamah. ( teu naros , hahahaha )
#
# # KEYWORDS
# <keyword>
# - Keyword: hahahaha
# - Analysis: The keyword "hahahaha" is a textual representation of laughter. According to the guidelines, laughter-like expressions, such as "hahaha," typically indicate the emotion of `joy`. This text doesn't seem to exhibit any sarcasm or irony that might alter the emotional context of the laughter. Additionally, within the context provided, "hahahaha" comes after a playful comment about not asking a question, suggesting a light-hearted and humorous tone. This further supports the idea that the emotion being conveyed here is one of amusement or happiness. The informal and playful nature of the conversation suggests that the person is having fun or expressing mild amusement, possibly at the fact that they have pre-empted the other party's possible question. Given this, the emotion of `joy` is clearly present in the text due to the presence of "hahahaha."
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Teu cukup sakali ngadangu keun na duh , tuluuuuunggg ,
#
# # KEYWORDS
# <keyword>
# - Keyword: tuluuuuunggg
# - Analysis: The keyword "tuluuuuunggg" is an elongated version of the Sundanese word "tulung," which translates to "help" or "assist" in English. The stretched-out way of writing indicates an expression of urgency or desperation. Whenever someone calls for help in such a manner, there's usually a strong emotion involved. Now, based on the guidelines, none directly applies to "tulung," so I need to analyze this further.
#
# Asking for help can involve various emotions. Firstly, fear could be a dominating emotion because the individual might be in a situation of peril or an unexpected development that's distressful and evokes fright. Another possibility is sadness, as feeling helpless could stem from emotional or physical distress, indicating an underlying state of sorrow or despair. Moreover, the repetitive and stretched nature implies a heightened level of anxiety or panic, further aligning with fear.
#
# Could it also suggest a surprise? Generally, if it were a sudden revelation or shock, there could be an element of surprise, but the focus here seems more directed at the need or cry for assistance, suggesting something more in terms of distress-related emotions. Therefore, surprise doesn't quite fit, as the emphasis is on seeking help.
#
# Given the request for help and the manner it is portrayed, the most encompassing emotions would likely be fear and possibly sadness. The urgency and repetition amplify the element of desperate fear.
# - Emotions: fear, sadness
# </keyword>
#
# <keyword>
# - Keyword: duh
# - Analysis: The word "duh" in Sundanese can carry different emotional weights depending on context. It often expresses a sense of frustration, exasperation, or lament. Now, based on the keyword "duh," it doesn't seem to match any specific guideline here, so I should consider its usage.
#
# Let's think about how "duh" functions in everyday expression. People might use it when they're overwhelmed, annoyed, or feeling regret. The context alongside the plea for help ("tuluuuuunggg") suggests a situation where the speaker is under stress or feels caught in an undesirable situation. Hmm, could this emphasize sadness? Yes, indeed. "Duh" often conveys discontent or emotional fatigue, which aligns with sadness.
#
# Could "duh" tie into anger? While not directly evident, when coupled with a cry for help, it could hint at underlying anger towards the situation or an inability to change it. However, it's more of a subtle possibility, whereas sadness and exasperation are clearer interpretations. There's also an undertone of hopelessness, which reinforces sadness.
#
# Overall, the word "duh" here carries a degree of sadness and perhaps hints slightly at frustration, but the predominant emotion, especially when combined with "tuluuuuunggg," is sadness.
# - Emotions: sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['fear', 'sadness']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 18 of 20
# ================================================================
# Predicting...
#
# # TEXT
# beuki geulis ieu budak mang anton halahhh, suksess terus ka sadayana
#
# # KEYWORDS
# <keyword>
# - Keyword: "halahhh"
# - Analysis: The keyword "halahhh" is quite interesting. It is often used in Sundanese and Indonesian contexts to express a dismissive or slightly sarcastic reaction. It can be likened to saying "oh please" or "yeah, right" in English. When considering this in the context where someone mentions a positive quality about a person and then follows it with "halahhh," it might imply a playful sense of disbelief or friendly teasing. This expression could indicate a light-hearted interaction rather than being driven by strong negative emotion. However, it does not seem to fit directly under any predefined emotion like `anger` or `fear`. On the contrary, this playful dismissiveness might simply enhance an atmosphere of `joy` because it indicates a level of familiarity or jest between people who are comfortable joking around. Furthermore, there might be an indirect indication of `surprise` if this reaction stems from unexpected praise or an unexpected quality attributed to someone. But primarily, the tone here is light-hearted and jovial.
# - Emotions: joy, surprise
# </keyword>
#
# <keyword>
# - Keyword: "suksess terus"
# - Analysis: The phrase "suksess terus" translates to "always successful" in English. This phrase is generally positive and exudes a sense of goodwill and encouragement. It's typically used to wish someone continued success and happiness. Taking this into account, such a sentiment aligns with the emotion of `joy` as it expresses happiness and positive anticipation for someone's future. Additionally, this encouragement holds a certain vibrancy that sparks a sense of optimism, which can also be linked to `joy`. However, although the sentiment is firmly rooted in positivity, there's an absence of tones that could suggest other emotions like `anger`, `fear`, `sadness`, or `surprise`. Thus, the encouragement and positive anticipation in this phrase unmistakably emphasize a joyful emotion throughout its use.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 19 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Jadi kieu mang urang teu bisa komentar, bejaan carana mang 😢
#
# # KEYWORDS
# <keyword>
# - Keyword: 😢
# - Analysis: The emoji 😢 is typically associated with sadness. It's a visual representation of crying, usually implying feelings of distress, disappointment, or sorrow. In the given text, this emoji appears after a statement about inability to comment, which suggests a feeling of helplessness or frustration. Since the guidelines state that 😭 could indicate joy in humorous contexts, it's relevant to consider whether 😢 might also be used in a context suggesting humor. However, the text does not seem humorous; it conveys a request for guidance or assistance due to an inability to comment. There's a sense of wanting help, which leans more towards sadness or possibly frustration. The context here doesn't suggest laughter or humor, so it's safe to align the emoji's meaning with its typical use. Moreover, this aligns with the standard emotional interpretation of this emoji. Therefore, this would primarily indicate sadness.
# - Emotions: sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 20 of 20
# ================================================================
# Predicting...
#
# # TEXT
# Hadir nengg., aa neng duh nyeri pisan euy d dyakeun ku awe2.,
#
# # KEYWORDS
# <keyword>
# - Keyword: nyeri pisan
# - Analysis: The phrase "nyeri pisan" translates to "very painful" in English. The use of "nyeri," which means "pain," suggests that there is an intense feeling of discomfort or hurt. In emotional terms, "pain" can relate to feelings of sadness or even anger, depending on the context. Now, considering this specific context—someone expressing a personal emotion by exclaiming "nyeri pisan"—it indicates a deep expression of suffering or distress. The addition of "pisan," meaning "very," intensifies this emotion, pointing to an experience of acute discomfort. In emotional analysis, this depth of agony can often be linked to deep sadness, as it signifies significant emotional hurt. Sometimes it could reflect anger if the pain stems from an injustice or betrayal, but the context provided here does not specify such circumstances. Overall, the phrase "nyeri pisan" primarily conveys sadness due to its implication of experiencing profound emotional pain.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: duh
# - Analysis: The interjection "duh" is often used to express various emotions like surprise, frustration, or concern. It's intriguing because it's not tethered to a singular emotion and can often depend on the contextual setting of its use. In this text, "duh" is used alongside "neng," an affectionate term, and "nyeri pisan," which signifies pain. Considering these elements together, "duh" likely underlines an element of concern or empathetic surprise in reaction to the mention of pain. This suggests that the speaker might be expressing a worried or troubling surprise at the intensity of the described pain, rather than excitement or shock. Still, the prevailing emotional theme in this phrase ties back to the primary feeling derived from "nyeri pisan," which is sadness, potentially with an added layer of concern because of "duh."
# - Emotions: surprise
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness', 'surprise']
#
# # TRUE EMOTIONS
# joy, sadness
#
# F1 Macro: 0.43402777777777773

# %% [markdown]
# ## Save Evaluation

# %%
# save_df = df.copy()
# save_df[emotion_cols] = y_pred
# save_df.to_csv('eval_sun.csv', index=False)
# print("Saved to: eval_sun.csv")
