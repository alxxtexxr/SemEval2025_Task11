# %% [markdown]
# # Libraries

# %%
import os
import json
import re
import pandas as pd
from datetime import datetime
from openai import OpenAI
from sklearn.metrics import f1_score
# from pprint import pprint

pd.set_option('max_colwidth', None)

# %% [markdown]
# # Config

# %%
seed = 42
client = OpenAI(api_key=json.load(open('secrets.json'))['OPENAPI_SECRET_KEY'])
idn2eng_emotion_map = {
    'marah': 'anger',
    'jijik': 'disgust',
    'takut': 'fear',
    'senang': 'joy',
    'sedih': 'sadness',
    'terkejut': 'surprise',
    'biasa': 'neutral',
}
prompt_paths = [
    # 'prompts/prompt_with_keywords_and_analysis.txt',
    'prompts/prompt_with_keywords.txt',
    'prompts/prompt_with_keywords_v3.txt',
    # 'prompts/prompt_with_keywords_and_intensity.txt',
    # 'prompts/prompt_with_keywords_v2.txt',
    # 'prompts/prompt_with_keywords_without_guidelines.txt'
]
prompt_evaluations_dir = 'prompt_evaluations'

# %% [markdown]
# # Data

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/preprocessed_data/track_a/sun_70_15_15_stratify_v2/val.csv')
df = df.rename(columns=idn2eng_emotion_map) # Translate emotion columns from Indonesian to English

print("DF size:", len(df))
df.head()
# Out:
# DF size: 128
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                    emotion  anger  disgust  fear  joy  sadness  surprise  \
# 0                   senang      0        0     0    1        0         0
# 1                   senang      0        0     0    1        0         0
# 2         senang, terkejut      0        0     0    1        0         1
# 3         senang, terkejut      0        0     0    1        0         1
# 4  senang, sedih, terkejut      0        0     0    1        1         1
#
#    neutral
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Remove data with 'neutral' emotion and the 'neutral' column
if 'neutral' in df.columns:
    df = df[~(df['neutral'] == 1)]  
    df = df.drop('neutral', axis=1) 

# Store emotion columns
emotion_cols = [col for col in df.columns if col not in ['Unnamed: 0', 'text', 'emotion', 'id']]
df['emotion'] = df.apply(lambda row: ', '.join([emotion for emotion in emotion_cols if row[emotion] == 1]), axis=1)

print("DF size (after removing emotion 'neutral'):", len(df))
print("Emotion columns:", emotion_cols)
df.head()
# Out:
# DF size (after removing emotion 'neutral'): 121
# Emotion columns: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                   emotion  anger  disgust  fear  joy  sadness  surprise
# 0                     joy      0        0     0    1        0         0
# 1                     joy      0        0     0    1        0         0
# 2           joy, surprise      0        0     0    1        0         1
# 3           joy, surprise      0        0     0    1        0         1
# 4  joy, sadness, surprise      0        0     0    1        1         1

# %% [markdown]
# # Evaluation

# %%
def get_prompt(prompt_path):
    prompt = None
    with open(prompt_path, 'r') as f:
        prompt = f.read()
    return prompt

def one_hot_encode_emotions(emotions, emotion_cols=emotion_cols):
    one_hot_emotion = [1 if emotion_col in emotions else 0 for emotion_col in emotion_cols]
    return one_hot_emotion

def get_pred_tag_content(prediction, tag_name):
    match = re.search(fr'<{tag_name}>(.*?)</{tag_name}>', prediction, re.DOTALL)
    tag_content = match.group(1).strip() if match else None
    return tag_content

def predict(text, prompt):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system', 'content': prompt},
            {'role': 'user', 'content': text},
        ],
        max_tokens=1000,
    )
    return completion.choices[0].message.content

prediction = predict(
    text="Cek urang mah jelema goblog teh nyaeta, jelema nu menta udud ngomong teu boga, padahal Aya sabungkus dinu pesak 😂🤣",
    prompt=get_prompt(prompt_paths[0]),
)

keywords_pred = get_pred_tag_content(prediction, 'keywords')
print("Precicted keywords and their analyses:")
print(keywords_pred)
print()

emotions_pred = get_pred_tag_content(prediction, 'emotions').lower().replace("." , "").replace(" ", "").split(",")
print("Precicted emotions:", emotions_pred, "->", one_hot_encode_emotions(emotions_pred))
# Out:
# Precicted keywords and their analyses:
# - goblog -> anger (Insult directed at someone)
# - 😂, 🤣 -> joy (Laughter emojis indicating humor or amusement)
#
# Precicted emotions: ['anger', 'joy'] -> [1, 0, 0, 1, 0, 0]

# %%
def eval_sampled(n, prompt_path):
    prompt = get_prompt(prompt_path)

    df_sampled = df.sample(n=n)
    y_true = df_sampled[emotion_cols].to_numpy()

    y_pred = []
    for i, v in enumerate(df_sampled.iterrows()):
        idx, row = v

        print("=" * 64)
        print(f"{i+1} OF {len(df_sampled)}")
        print("=" * 64)

        is_valid = True

        while True:
            print("Predicting...")        

            prediction = predict(row['text'], prompt)
            keywords_pred = get_pred_tag_content(prediction, 'keywords')
            emotions_pred = get_pred_tag_content(prediction, 'emotions').replace(" ", "").split(",")
            emotions_pred_one_hot = one_hot_encode_emotions(emotions_pred, emotion_cols)

            is_valid = bool(sum(emotions_pred_one_hot))

            if is_valid:
                break
            else:
                print("Error! Prediction:", prediction)
                print()
            
        y_pred.append(emotions_pred_one_hot)

        print()
        print("# TEXT")
        print(row['text'])
        print()
        print("# KEYWORDS")
        print(keywords_pred)
        print()
        print("# PREDICTED EMOTIONS")
        print(emotions_pred)
        print()
        print("# TRUE EMOTIONS")
        print(row['emotion'])
        print()

    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=1.0)
    f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=1.0)
    f1_labels = f1_score(y_true, y_pred, average=None, zero_division=1.0)
    f1_labels_dict = {f'f1_label_{emotion_cols[i]}': float(f1_labels[i]) for i in range(len(f1_labels))}

    return {
        'prompt_path': prompt_path,
        'n': n,
        'f1_macro': float(f1_macro),
        'f1_micro': float(f1_micro),
        **f1_labels_dict,
    }

prompt_eval = []
for prompt_path in prompt_paths:
    print("=" * 128)
    print("PROMPT PATH:", prompt_path)
    print("=" * 128)

    evaluation = eval_sampled(n=20, prompt_path=prompt_path)
    print("Evaluation:")
    print(evaluation)

    prompt_eval.append(evaluation)
    
    print()
# Out:
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nongton iklan nepi ka tamat ,😭
#
# # KEYWORDS
# - 😭 -> joy (In humorous contexts, such as watching ads to the end, it often represents extreme laughter that brings tears.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kang abi mah request sanes lagu tp hoyong ningali feat kang sule salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda 🙏🙏🙏
#
# # KEYWORDS
# - hoyong ningali -> joy (expresses a desire or hope to see something)
# - salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda -> pride, joy (expresses admiration and appreciation for a Sundanese artist who values Sundanese culture)
#
# # PREDICTED EMOTIONS
# ['joy', 'pride']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang resep musikna ceria teu melow ngenah jang jingkrak2 hahahha
#
# # KEYWORDS
# - ceria -> joy (positive, lively mood)
# - jingkrak2 -> joy (expression of excitement and dancing)
# - hahahha -> joy (indicates laughter)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kamari urang maok buah Terus?? Hanjakal aya nu boga na
#
# # KEYWORDS
# - maok (steal) -> fear (fear of getting caught or consequences)
# - hanjakal (unfortunately) -> sadness (regret for the outcome)
#
# # PREDICTED EMOTIONS
# ['fear', 'sadness']
#
# # TRUE EMOTIONS
# surprise
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Abdi bakal nyeri kalau di miduakeun ku Azmy.z
#
# # KEYWORDS
# - nyeri -> sadness (the text speaks about feeling hurt)
# - miduakeun -> fear (refers to being cheated on and the fear of being in a secondary position)
#
# # PREDICTED EMOTIONS
# ['sadness', 'fear']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang urang subscribers maneh tapi urang ngadukung persija tapi.teu nanaonlah nu penting urang resep vidio nu di upload ku maneh. #VIKJAK.
#
# # KEYWORDS
# - resep -> joy (expressing liking or enjoyment for the videos uploaded)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Q: Kurang naon anu nyieun bingung? A: Kurang kerung Wkwk
#
# # KEYWORDS
# - Wkwk -> joy (indicates laughter or amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Assalamualaikum, kang lamun bade order acuk aya di lazada teu?
#
# # KEYWORDS
# - Assalamualaikum -> joy (greeting with peace)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang teu ngarti arti lagu na, tapi asa ngena euy kanu hate
#
# # KEYWORDS
# - ngarti -> sadness (lack of understanding can cause sadness)
# - ngena -> sadness (something that touches the heart often evokes sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Saha anu bisa ngasupkeun jeung sikina,
#
# # KEYWORDS
# - bisa -> joy (suggests capability and opportunity)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Di Sunda mah teu aya nu teu lucu, kabeh geh lucu orang Sunda mah😆Satujuu wkwk
#
# # KEYWORDS
# - lucu -> joy (referring to humor and fun)
# - 😆 -> joy (smiling/laughing emoji)
# - wkwk -> joy (laughter-like expression indicating humor)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# sarua ajig teu ngarti tapi sediih, sedih ku teu ngarti ajiig,
#
# # KEYWORDS
# - ajig -> anger (an insult term indicating strong negative emotion)
# - sediih, sedih -> sadness (explicit mention of feeling sad due to not understanding)
#
# # PREDICTED EMOTIONS
# ['anger', 'sadness']
#
# # TRUE EMOTIONS
# anger, sadness
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Ulah kitu atuh mang, komen kritik ieu teh kudu ditarima lain dibales hate kitu. Goreng ka mamang nageh ke loba nu te resep. Sing bageur ka penonton teh atuh. Minimal ulah nyieun tersinggung.
#
# # KEYWORDS
# - kritik -> sadness (indicating the critique might be negatively received)
# - hate -> anger (emotion felt when responding with hate)
# - goreng -> anger (discontentment is suggested by this word towards the recipient)
# - loba nu te resep -> sadness (implies many people might be unhappy or disapprove)
# - tersinggung -> sadness (being offended or hurt)
#
# # PREDICTED EMOTIONS
# ['anger', 'sadness']
#
# # TRUE EMOTIONS
# anger, disgust
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Curiga dekah anu make kacamata si Asep
#
# # KEYWORDS
# - curiga -> fear (suspicion often involves fear of something being wrong or harmful)
#
# # PREDICTED EMOTIONS
# ['fear']
#
# # TRUE EMOTIONS
# surprise
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# karunya si apil nu ngajieuna ehh juned nu tenarna haha😂
#
# # KEYWORDS
# - karunya -> sadness (expresses pity)
# - haha😂 -> joy (laughter and laughing emoji)
#
# # PREDICTED EMOTIONS
# ['sadness', 'joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Enakeun nih lagu buat pas hajatan hhe
#
# # KEYWORDS
# - Enakeun -> joy (indicates pleasure or enjoyment)
# - hhe -> joy (expression similar to laughter)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Jadi kieu mang urang teu bisa komentar, bejaan carana mang 😢
#
# # KEYWORDS
# - teu bisa komentar -> sadness (expressing inability or frustration)
# - 😢 -> sadness (crying emoji indicates sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# mang aslina ti daerah mana sih mang? abdimah asli ti rajamandala bandung barat, tapi calik di balaraja banten ayeunamah. ( teu naros , hahahaha )
#
# # KEYWORDS
# - hahahaha -> joy (laughter expression indicating amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kur aya jang ongkos ngan eweuh jang dahar :((
#
# # KEYWORDS
# - eweuh jang dahar -> sadness (due to lack of food)
# - :(( -> sadness (emoticon indicating unhappiness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# nyeri kulit beuteung ieu, gehel MANTABS, MANTABS LUR 2thumbup
#
# # KEYWORDS
# - nyeri kulit beuteung -> sadness (discomfort or pain expressed)
# - MANTABS, MANTABS LUR 2thumbup -> joy (enthusiastic and positive expression, use of "MANTABS" indicating excitement or approval)
#
# # PREDICTED EMOTIONS
# ['sadness', 'joy']
#
# # TRUE EMOTIONS
# joy
#
# Evaluation:
# {'prompt_path': 'prompts/prompt_with_keywords.txt', 'n': 20, 'f1_macro': 0.4523809523809524, 'f1_micro': 0.7755102040816326, 'f1_label_anger': 1.0, 'f1_label_disgust': 0.0, 'f1_label_fear': 0.0, 'f1_label_joy': 1.0, 'f1_label_sadness': 0.7142857142857143, 'f1_label_surprise': 0.0}
#
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords_v3.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Aduh eta mang asep balon kuat jiga anu enakeun joged na, 👍👍
#
# # KEYWORDS
# - enakeun -> joy (expressing something enjoyable)
# - 👍👍 -> joy (thumbs up emoji indicating a positive or enjoyable sentiment)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Curiga dekah anu make kacamata si Asep
#
# # KEYWORDS
# - Curiga -> fear (suspicion often implies a sense of fear or concern about something or someone)
#
# # PREDICTED EMOTIONS
# ['fear']
#
# # TRUE EMOTIONS
# surprise
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Eh, neng alma karak aya deui,
#
# # KEYWORDS
# - karak aya -> surprise (the phrase suggests something unexpected or just discovered)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hadir ah bisi pajar keun lain urang Sunda 🤣🤣
#
# # KEYWORDS
# - 🤣 -> joy (expression of laughter)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nyeri kulit beteung pas ningali nu nga goreng,
#
# # KEYWORDS
# - nyeri kulit -> sadness (discomfort or pain)
# - beteung -> anger (frustration)
#
# # PREDICTED EMOTIONS
# ['sadness', 'anger']
#
# # TRUE EMOTIONS
# anger, disgust, surprise
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Tos karasa geing ayeunamah kiyeu kahirupan teh jero sajero hatiku yang terluka
#
# # KEYWORDS
# - terluka -> sadness (the word reflects emotional pain or hurt)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Adi jeung lanceuk ieu teh ? Aduh bingung rek milih anu mana sarua mojang bandung 😂😅
#
# # KEYWORDS
# - bingung -> surprise (feeling confused about making a decision)
# - 😂 -> joy (laughter-like expression indicating amusement)
# - 😅 -> joy (laughter-like expression indicating amusement)
#
# # PREDICTED EMOTIONS
# ['surprise', 'joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Cisitu mana aya teu? 😂 tapi ayeuna ngalih ka parakan muncang 😂
#
# # KEYWORDS
# - 😂 -> joy (laughter-like expression)
# - ngalih (move) -> surprise (indicates a change or unexpected movement)
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Teuing ku naon kabeh lagu nu di nyanyikeun neng bintan urng resep kabeh, eta sora d jampean d dukun mana neng, 🤣🤣🤣
#
# # KEYWORDS
# - resep (like) -> joy (expresses enjoyment)
# - 🤣🤣🤣 (laughing emoji) -> joy (expresses laughter and amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lebaran Taun ayeuna bisa karumpul jeung klwrga moal nya mang. ? Aya korona ayna mah euy jdi sedih 😭😭😭😭
#
# # KEYWORDS
# - karumpul -> joy (being with family typically brings joy)
# - korona -> fear (pandemic situation is typically associated with fear)
# - sedih -> sadness (explicitly states feeling of sadness)
# - 😭 -> joy (in humorous context, used to express extreme laughter)
#
# # PREDICTED EMOTIONS
# ['joy', 'fear', 'sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Zodiak urang neptunus, ning teu dijelaskeun :(
#
# # KEYWORDS
# - teu dijelaskeun -> sadness (feeling of being left out or ignored)
# - :( -> sadness (sad face emoji)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# joy, sadness
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang teu ngarti arti lagu na, tapi asa ngena euy kanu hate
#
# # KEYWORDS
# - ngarti -> sadness (lack of understanding can cause frustration or sadness)
# - ngena -> sadness (feeling touched or emotional)
# - hate -> sadness (refers to feelings or heart, often associated with deeper emotions)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Rek nantangan ngadar seblak pang ladaana sakota bandung duaan jeung mang koko wkkwkw resep sigana,
#
# # KEYWORDS
# - wkkwkw -> joy (indicates laughter or amusement)
# - resep -> joy (means enjoyment or liking)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Unfaedah tapi dugi nyeri kulit beuteung 🤣🤣🤣
#
# # KEYWORDS
# - nyeri kulit beuteung -> joy (expressed humor despite describing discomfort)
# - 🤣🤣🤣 -> joy (laughter emojis indicating humor)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lanjutkeun Mang hade pisan lahh. Sunda Is The Best 👍
#
# # KEYWORDS
# - hade pisan -> joy (expresses high appreciation)
# - Sunda Is The Best -> joy (expresses pride and positive sentiment)
# - 👍 -> joy (thumbs-up emoji indicating agreement or approval)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# karunya si apil nu ngajieuna ehh juned nu tenarna haha😂
#
# # KEYWORDS
# - karunya -> sadness (expression of pity or compassion)
# - haha 😂 -> joy (laughter and joy emoji indicate humor)
#
# # PREDICTED EMOTIONS
# ['sadness', 'joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lin kadua atoh heu jadi buming deui ku 3 pemuda berbahaya lagu ieu th
#
# # KEYWORDS
# - atoh -> joy (happiness or excitement about something)
# - buming -> joy (success or popularity)
# - berbahaya -> fear (something dangerous or risky)
#
# # PREDICTED EMOTIONS
# ['joy', 'fear']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Pokok namah sok aya pikalucuen nana boga adi lalaki, Alhamdulilah ka allaman, Saee pikaserieun mang fiksi vidiona, Sukses trus mangg,
#
# # KEYWORDS
# - pikalucuen -> joy (expresses humor)
# - Alhamdulilah -> joy (expression of gratitude)
# - Saee pikaserieun -> joy (expresses amusement or laughter)
# - Sukses trus -> joy (wishing success, positive sentiment)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# sabaraha gereget kamari urang nginum cai caina di picen gelas na di uyup😂😂😂😂😂
#
# # KEYWORDS
# - 😂 -> joy (laughter emoji indicating humor or amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Absen ti bogor katingaleun vidiona Sing barokah rizkinna lah mag fiksi
#
# # KEYWORDS
# - barokah -> joy (indicates a blessing or good fortune)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# Evaluation:
# {'prompt_path': 'prompts/prompt_with_keywords_v3.txt', 'n': 20, 'f1_macro': 0.523499361430396, 'f1_micro': 0.7407407407407407, 'f1_label_anger': 1.0, 'f1_label_disgust': 0.0, 'f1_label_fear': 0.0, 'f1_label_joy': 0.896551724137931, 'f1_label_sadness': 0.8, 'f1_label_surprise': 0.4444444444444444}

# %%
prompt_eval
# Out:
# [{'prompt_path': 'prompts/prompt_with_keywords.txt',
#   'n': 20,
#   'f1_macro': 0.4523809523809524,
#   'f1_micro': 0.7755102040816326,
#   'f1_label_anger': 1.0,
#   'f1_label_disgust': 0.0,
#   'f1_label_fear': 0.0,
#   'f1_label_joy': 1.0,
#   'f1_label_sadness': 0.7142857142857143,
#   'f1_label_surprise': 0.0},
#  {'prompt_path': 'prompts/prompt_with_keywords_v3.txt',
#   'n': 20,
#   'f1_macro': 0.523499361430396,
#   'f1_micro': 0.7407407407407407,
#   'f1_label_anger': 1.0,
#   'f1_label_disgust': 0.0,
#   'f1_label_fear': 0.0,
#   'f1_label_joy': 0.896551724137931,
#   'f1_label_sadness': 0.8,
#   'f1_label_surprise': 0.4444444444444444}]

# %% [markdown]
# ## Save Evaluation

# %%
with open(os.path.join(prompt_evaluations_dir, f'prompt_eval_{datetime.now().strftime("%Y%m%d%H%M%S")}.json'), 'w') as f:
    json.dump(prompt_eval, f, indent=4)

# %% [markdown]
# ## View Saved Evaluations

# %%
prompt_eval_names = os.listdir(prompt_evaluations_dir)
prompt_eval_dfs = [pd.read_json(os.path.join(prompt_evaluations_dir, prompt_eval_name)) for prompt_eval_name in prompt_eval_names]

concat_df = pd.concat(prompt_eval_dfs).groupby('prompt_path', as_index=False)
mean_df = concat_df.mean()
sum_df = concat_df.sum()
mean_df['n'] = sum_df['n']
mean_df
# Out:
#                                            prompt_path    n  f1_macro  \
# 0                     prompts/prompt_with_keywords.txt  300  0.557041
# 1        prompts/prompt_with_keywords_and_analysis.txt   60  0.517154
# 2       prompts/prompt_with_keywords_and_intensity.txt   40  0.437113
# 3                  prompts/prompt_with_keywords_v2.txt  120  0.541275
# 4                  prompts/prompt_with_keywords_v3.txt  100  0.540339
# 5  prompts/prompt_with_keywords_without_guidelines.txt   40  0.517654
#
#    f1_micro  f1_label_anger  f1_label_disgust  f1_label_fear  f1_label_joy  \
# 0  0.755982        0.664444          0.533333       0.166667      0.920761
# 1  0.706220        0.500000          0.666667       0.000000      0.851478
# 2  0.704407        0.333333          0.500000       0.000000      0.876157
# 3  0.740009        0.388889          0.666667       0.166667      0.872351
# 4  0.709677        0.931429          0.133333       0.200000      0.863289
# 5  0.667641        0.250000          1.000000       0.000000      0.873016
#
#    f1_label_sadness  f1_label_surprise
# 0          0.841040           0.216003
# 1          0.779221           0.305556
# 2          0.813187           0.100000
# 3          0.874038           0.279040
# 4          0.824444           0.289538
# 5          0.717949           0.264957
