# %% [markdown]
# # Libraries

# %%
import json
import re
import pandas as pd
from openai import OpenAI
from sklearn.metrics import f1_score
# from pprint import pprint

pd.set_option('max_colwidth', None)

# %% [markdown]
# # Config

# %%
seed = 42
client = OpenAI(api_key=json.load(open('secrets.json'))['OPENAPI_SECRET_KEY'])
idn2eng_emotion_map = {
    'marah': 'anger',
    'jijik': 'disgust',
    'takut': 'fear',
    'senang': 'joy',
    'sedih': 'sadness',
    'terkejut': 'surprise',
    'biasa': 'neutral',
}
prompt_paths = [
    'prompts/prompt_with_keywords_and_analysis.txt',
    'prompts/prompts_with_keywords.txt',
]

# %% [markdown]
# # Data

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/preprocessed_data/track_a/sun_70_15_15_stratify_v2/val.csv')
df = df.rename(columns=idn2eng_emotion_map) # Translate emotion columns from Indonesian to English

print("DF size:", len(df))
df.head()
# Out:
# DF size: 128
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                    emotion  anger  disgust  fear  joy  sadness  surprise  \
# 0                   senang      0        0     0    1        0         0
# 1                   senang      0        0     0    1        0         0
# 2         senang, terkejut      0        0     0    1        0         1
# 3         senang, terkejut      0        0     0    1        0         1
# 4  senang, sedih, terkejut      0        0     0    1        1         1
#
#    neutral
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Remove data with 'neutral' emotion and the 'neutral' column
if 'neutral' in df.columns:
    df = df[~(df['neutral'] == 1)]  
    df = df.drop('neutral', axis=1) 

# Store emotion columns
emotion_cols = [col for col in df.columns if col not in ['Unnamed: 0', 'text', 'emotion', 'id']]
df['emotion'] = df.apply(lambda row: ', '.join([emotion for emotion in emotion_cols if row[emotion] == 1]), axis=1)

print("DF size (after removing emotion 'neutral'):", len(df))
print("Emotion columns:", emotion_cols)
df.head()
# Out:
# DF size (after removing emotion 'neutral'): 121
# Emotion columns: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                   emotion  anger  disgust  fear  joy  sadness  surprise
# 0                     joy      0        0     0    1        0         0
# 1                     joy      0        0     0    1        0         0
# 2           joy, surprise      0        0     0    1        0         1
# 3           joy, surprise      0        0     0    1        0         1
# 4  joy, sadness, surprise      0        0     0    1        1         1

# %% [markdown]
# # Evaluation

# %%
def get_prompt(prompt_path):
    prompt = None
    with open(prompt_path, 'r') as f:
        prompt = f.read()
    return prompt

def one_hot_encode_emotions(emotions, emotion_cols=emotion_cols):
    one_hot_emotion = [1 if emotion_col in emotions else 0 for emotion_col in emotion_cols]
    return one_hot_emotion

def get_pred_tag_content(prediction, tag_name):
    match = re.search(fr'<{tag_name}>(.*?)</{tag_name}>', prediction, re.DOTALL)
    tag_content = match.group(1).strip() if match else None
    return tag_content

def predict(text, prompt):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system', 'content': prompt},
            {'role': 'user', 'content': text},
        ],
        max_tokens=1000,
    )
    return completion.choices[0].message.content

prediction = predict(
    text="Cek urang mah jelema goblog teh nyaeta, jelema nu menta udud ngomong teu boga, padahal Aya sabungkus dinu pesak 😂🤣",
    prompt=get_prompt(prompt_paths[0]),
)

keywords_pred = get_pred_tag_content(prediction, 'keywords')
print("Precicted keywords and their analyses:")
print(keywords_pred)
print()

emotions_pred = get_pred_tag_content(prediction, 'emotions').lower().replace("." , "").replace(" ", "").split(",")
print("Precicted emotions:", emotions_pred, "->", one_hot_encode_emotions(emotions_pred))
# Out:
# Precicted keywords and their analyses:
# <keyword>
# - Keyword: goblog
# - Analysis: The word "goblog" in Sundanese translates to "stupid" or "idiot" in English. This term is typically used as an insult, and according to the guidelines, insults are generally associated with both `anger` and `disgust`. Using such a term suggests that the speaker is expressing a strong negative emotion towards the person they are referring to, possibly because they believe the person's actions do not make sense. It is an expression that reflects a frustration or disdain for perceived foolishness or incompetence.
# - Emotions: anger, disgust
# </keyword>
#
# <keyword>
# - Keyword: 😂🤣
# - Analysis: The emojis 😂 and 🤣 are both representations of laughter and are typically used to indicate something is extremely funny or amusing. Referring to the guidelines, laughter-like expressions, especially emojis of this nature, usually indicate `joy`. In the context of the sentence, the use of these emojis suggests that the speaker finds the situation humorously absurd or ridiculous. Despite the insult with the word "goblog," these emojis show that the speaker is not entirely serious or perhaps sees the humor in the person's contradictory behavior.
# - Emotions: joy
# </keyword>
#
# Precicted emotions: ['anger', 'disgust', 'joy'] -> [1, 1, 0, 1, 0, 0]

# %%
def eval_sampled(n, prompt):
    df_sampled = df.sample(n=n)
    y_true = df_sampled[emotion_cols].to_numpy()

    y_pred = []
    for i, v in enumerate(df_sampled.iterrows()):
        idx, row = v

        print("=" * 64)
        print(f"{i+1} OF {len(df_sampled)}")
        print("=" * 64)

        is_valid = True

        while True:
            print("Predicting...")        

            prediction = predict(row['text'], prompt)
            keywords_pred = get_pred_tag_content(prediction, 'keywords')
            emotions_pred = get_pred_tag_content(prediction, 'emotions').replace(" ", "").split(",")
            emotions_pred_one_hot = one_hot_encode_emotions(emotions_pred, emotion_cols)

            is_valid = bool(sum(emotions_pred_one_hot))

            if is_valid:
                break
            else:
                print("Error! Prediction:", prediction)
                print()
            
        y_pred.append(emotions_pred_one_hot)

        print()
        print("# TEXT")
        print(row['text'])
        print()
        print("# KEYWORDS")
        print(keywords_pred)
        print()
        print("# PREDICTED EMOTIONS")
        print(emotions_pred)
        print()
        print("# TRUE EMOTIONS")
        print(row['emotion'])
        print()

    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=1.0)
    f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=1.0)
    f1_labels = f1_score(y_true, y_pred, average=None, zero_division=1.0)
    f1_labels_dict = {f'f1_label_{emotion_cols[i]}': float(f1_labels[i]) for i in range(len(f1_labels))}

    return {
        'f1_macro': float(f1_macro),
        'f1_micro': float(f1_micro),
        **f1_labels_dict,
    }

prompt_evaluations = []
for prompt_path in prompt_paths:
    print("=" * 128)
    print("PROMPT PATH:", prompt_path)
    print("=" * 128)

    evaluation = eval_sampled(n=20, prompt=get_prompt(prompt_path))
    print("Evaluation:")
    print(evaluation)

    prompt_evaluations.append({prompt_path: evaluation})
    
    print()
# Out:
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords_and_analysis.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Geuning geus numbub deui kumisna wkwkwk
#
# # KEYWORDS
# <keyword>
# - Keyword: wkwkwk
# - Analysis: The text includes the expression "wkwkwk," which commonly represents the sound of laughter in casual online communication, particularly in Indonesian and Sundanese cultures. This expression is typically used to indicate amusement or humor in a conversation. According to the guidelines, laughter-like expressions such as "hahaha," "wkwkw," or similar suggest the emotion of joy. The presence of "wkwkwk" in the sentence implies a light-hearted or humorous reaction to the preceding statement about someone's mustache having grown back. The use of "wkwkwk" is not associated with any negative emotions such as anger, sadness, or fear. Instead, it indicates that the speaker finds the situation funny or amusing. Therefore, this laughter expression points towards the overall emotion being joy in this context, as it suggests that the speaker is likely entertained, in a good mood, or making a joke about the mustache's return.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# a: buah naon nu matak bingung? b: kadu/teu apal a: apel b: hah? naha apel? a: tah pan bingung aya deui a: gajah ngapung katingali naon na? b: suku a: salah, katingali bohong na atuh
#
# # KEYWORDS
# <keyword>
# - Keyword: bingung
# - Analysis: The term "bingung" translates to "confused" in English. In the context of the joke involving fruits that cause confusion, the term is used to set up a playful interaction meant to generate humor rather than genuine disorientation. This is evident in the play on words with "apel," which can mean both the fruit and a kind of gathering or presence, creating a pun that results in laughter or amusement rather than genuine confusion. This verbal play is typical in jokes, where the intention is to evoke `joy` in the audience through clever wordplay.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: hah?
# - Analysis: The expression “hah?” is typically a reaction of surprise or confusion. In this context, it could represent a brief moment of confusion due to the unexpected punchline of the joke. However, since this is a joke, the "hah?" could also be part of the comedic effect, allowing the recipient to express both surprise and amusement. Considering the context of the entire exchange, the surprise leads to amusement or laughter, reinforcing the emotion of `joy`.
# - Emotions: surprise, joy
# </keyword>
#
# <keyword>
# - Keyword: bohong
# - Analysis: Translating to "lie" or "deception," "bohong" in the context of a joke about flying elephants reveals the absurdity or untruthfulness of such a statement. The purpose of highlighting the deception ("katingali bohong na") is to deliver a punchline that subverts expectations and results in laughter. The use of absurd imagery in jokes is intended to surprise the listener and elicit a humorous reaction. Therefore, in this context, "bohong" guides the recipient towards recognizing the joke's nature, which relies on surprise for comedic effect, thus resulting in `joy`.
# - Emotions: joy, surprise
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Duuuh mani raos pisan neng Azmii 😍, diulangulang , dipilari deui, dikuping deui , masih raos wae , kumaha atuuh makin terazmi azmi, sundana gaskeuuun 😘
#
# # KEYWORDS
# <keyword>
# - Keyword: raos pisan
# - Analysis: The phrase "raos pisan" in Sundanese can be translated to "very delicious" or "very enjoyable" in English. This expression suggests a strong sense of pleasure, satisfaction, or delight. When someone mentions that something is "raos pisan," they are likely expressing joy or a high liking for the subject being discussed. In this context, it reflects a deep appreciation or enjoyment of the situation involving neng Azmii, potentially referring to her charm or pleasant company. Considering the context of the sentence, which includes emojis typically associated with positive emotions, the overall sentiment is indeed joyful.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: 😍
# - Analysis: According to the guidelines, smile or heart-eye emojis like 😍 typically indicate joy. The heart-eye emoji represents admiration, affection, or love, which inherently carries a joyful connotation. Given this established guideline, the presence of the 😍 emoji in the text is a clear signal of joy, excitement, and infatuation towards the subject, neng Azmii.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: diulangulang, dipilari deui, dikuping deui
# - Analysis: "Diulangulang" means "repeatedly," "dipilari deui" translates to "searched again," and "dikuping deui" means "listened to again." These repeated actions signify an intense interest or affection towards something. When people engage in such behaviors, it usually stems from a strong emotional attachment or a profound enjoyment of the experience, suggesting joy and excitement. Within the context of the text, these actions enhance the sense of joy and enthusiasm associated with neng Azmii.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: makin terazmi azmi
# - Analysis: "Makin terazmi" could be interpreted as "becoming more like Azmi," where "terazmi" is a playful version involving someone's name. This phrase complements the overall lighthearted and joyful tone of the message by conveying admiration or humorous intent. The use of wordplay and personalization often reflects an affectionate or playful interaction, which strengthens the emotion of joy associated with the text.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: 😘
# - Analysis: According to the guidelines, smile or kiss emojis like 😘 usually indicate joy. The kiss emoji expresses affection, fondness, or love, aligning with positive emotions like joy. In this context, the 😘 emoji reinforces the affectionate and joyful sentiment expressed throughout the text regarding neng Azmii.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# bah dukun ka ramayana hatur nuhun sadayana
#
# # KEYWORDS
# <keyword>
# - Keyword: hatur nuhun
# - Analysis: Let's start by translating the keyword "hatur nuhun" from Sundanese to English. It means "thank you." Typically, expressions of gratitude are associated with positive emotions. They convey appreciation and a sense of goodwill. I should consider what kind of emotions are often tied to saying thank you. Gratitude often brings joy, as it reflects happiness and contentment with what one has received or experienced. By expressing gratitude, the speaker might be feeling a sense of joy or satisfaction. There might not appear to be a direct guideline concerning gratitude, but joy aligns quite accurately considering the emotional undertone of being thankful. Maybe there's an element of respect or acknowledgment? Well, "hatur nuhun" certainly carries respect, but the most pronounced emotion seems to be joy from a successful or helpful interaction. Let me consider other contexts... Could "hatur nuhun" imply any other emotions? Fear or anger doesn't really fit here. Sadness might only be indirectly related, like being content after resolving a prior issue, but fundamentally, "hatur nuhun" typically invokes positive sentiments like joy or relief. So, overall, the expression of gratitude here really aligns most strongly with the emotion of joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kamari urang aing labuh ti sapeda tapi teu berdarah sapedahna NU getihan
#
# # KEYWORDS
# <keyword>
# - Keyword: labuh
# - Analysis: The word "labuh" in Sundanese translates to "fall" in English. Falling typically relates to a sudden and unexpected event, which can cause various emotions. Commonly, falling could involve surprise because it is usually spontaneous and catches the person off guard. There might also be elements of fear depending on the perceived severity of the fall, which could lead to concerns about injury or damage. Additionally, the context requires a distinction between physical pain or harm associated with a fall, which potentially induces fear rather than anger. Here, there is an indication that the fall resulted in no physical harm ("teu berdarah"), meaning that while the event was perhaps shocking or unexpected, there is an absence of immediate distress from physical injury. This fact could mitigate some fear and could even introduce a slight element of relief or humor, though not explicitly joy. Therefore, considering the situation, the emotions associated could primarily revolve around surprise and potentially a mild fear, though minimized by the lack of injury.
# - Emotions: surprise, fear
# </keyword>
#
# <keyword>
# - Keyword: getihan
# - Analysis: The word "getihan" translates to "bloodied" in English. In this context, it refers to the bicycle being bloodied, which may create a visceral image. Such a visual could initially invoke shock or discomfort upon realization. The primary emotional response linked to blood or injury could often lead to fear due to its association with pain or harm. However, the phrase states that it is the bicycle, not the person, that is bloodied, minimizing direct concern about personal harm. The separation from the self could mediate the intensity of fear, transforming it to surprise or a sense of peculiarity, especially considering the incongruity of a bloodied object versus personal injury. The narrative seems to deflect serious harm to the individual, lightening the tone. In some cases, the incongruity or misleading anxiety about damage shifted to the object might amuse rather than alarm, adding a subtle humor. Ultimately, the predominant emotions are surprise at the unexpected and slightly unsettling imagery and a muted fear due to implications of bodily harm.
# - Emotions: surprise, fear
# </keyword>
#
# # PREDICTED EMOTIONS
# ['surprise', 'fear']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Pokok namah sok aya pikalucuen nana boga adi lalaki, Alhamdulilah ka allaman, Saee pikaserieun mang fiksi vidiona, Sukses trus mangg,
#
# # KEYWORDS
# <keyword>
# - Keyword: pikalucuen
# - Analysis: The word "pikalucuen" in Sundanese translates to "funny" in English. This keyword suggests a sense of amusement and light-heartedness. Funny things generally evoke laughter and smiles, associated with joy. According to the guidelines, expressions that indicate amusement and fun, like "hahaha," usually indicate joy. Since laughter is a response to humor, and humor is linked to happiness, the emotion here aligns with joy. The context provided by the rest of the text seems to reflect a positive and humorous experience, as implied by the reference to a sibling and a positive expression like "Alhamdulilah" and "Saee pikaserieun," reinforcing the joy experienced due to something funny.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: Alhamdulilah
# - Analysis: "Alhamdulilah" translates to "Praise be to God" in English. It's a common expression of gratitude, relief, or satisfaction. When people express gratitude, they often experience joy or relief. In this context, the speaker is grateful, possibly because of good things involving their brother or because of a humorous or positive video. The gratitude here suggests an underlying joy or contentment with the situation. Since it's expressed in conjunction with a humorous element ("pikalucuen"), it adds to the overall sense of joy from this expression of satisfaction and contentment.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: Saee pikaserieun
# - Analysis: "Saee pikaserieun" can be translated to "good to laugh" or "funny." This phrase directly denotes an action or feeling of laughter, relating strongly to amusement and joy. According to the guidelines, expressions involving laughter suggest joy. The act of laughing is deeply connected to joy because it's a physical manifestation of happiness and relief. Therefore, "Saee pikaserieun" implies that the situation or content (possibly the video mentioned) was indeed light-hearted and fun, leading to a joyful experience. This further complements the overall positive and joyful theme conveyed in the text.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: vidiona
# - Analysis: The term "vidiona" refers to "the video" in English. In this context, the video is described positively, indicating that it was a source of entertainment or laughter. Given the surrounding keywords and phrases like "pikalucuen" and "Saee pikaserieun," it's logical to infer that the video is humorous or enjoyable. Videos that make people laugh or feel entertained usually elicit joy in viewers. Hence, even though the video itself is not an emotion, its nature implied by the context leads to experiencing joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang fiksi urang ti garut Urang bungah pisan ngadangu na ge euy Bener pisan lagu teh ngamumule basa sunda teh mun teu ku urang ku saha deui Mun lain ti urang ti saha deui Sehat mang fiksi💪💪
#
# # KEYWORDS
# <keyword>
# - Keyword: bungah
# - Analysis: The keyword "bungah" translates to "happy" or "joyful" in English. It's a direct emotional expression of joy or happiness. Considering the context, "bungah" is used to describe the speaker's emotional reaction upon hearing some news or music that they find culturally significant. The text expresses pride and joy at the preservation of the Sundanese language through songs, emphasizing a sense of cultural identity and responsibility. The use of the word "bungah" here aligns directly with the context of celebrating cultural heritage, which is a source of joy for the speaker. Therefore, the presence of "bungah" in this text unmistakably points to the emotion of joy.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: sehat
# - Analysis: The word "sehat" translates to "healthy" in English. In this context, "sehat" is used in a positive and supportive manner, wishing someone good health. While "sehat" itself isn't an emotion, the act of wishing someone good health often comes from a place of care and positive regard, which can be associated with joy. It expresses a positive sentiment towards the person addressed as "mang fiksi," strengthening the overall tone of goodwill and happiness. This positive concern for someone's well-being complements the joy expressed earlier in the text.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: 💪💪
# - Analysis: The arm flexing emoji 💪 is often used to convey strength, encouragement, or support. While not inherently linked to an emotion by the guidelines, it typically accompanies positive sentiments like motivation, triumph, or sometimes excitement, which can connect to joy. In this context, the emojis are used to express strength and support towards "mang fiksi," enhancing the positive tone of the message. The use of these emojis alongside expressions of happiness and cultural pride reinforces the collective spirit and joy in the message.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
#
# # KEYWORDS
# <keyword>
# - Keyword: ":v"
# - Analysis: Hmm... let's think about ":v." In many online contexts, this emoji is often used to represent a playful or teasing mood. It might not directly represent an extreme emotion like laughter or anger, but it usually indicates light-heartedness or joking. In the text, this emoji appears twice, suggesting not one but potentially a reinforcing playful tone. Now, according to the guidelines, the presence of smile or laugh emojis like this typically indicates 'joy.' The way it's used here seems to fit a playful, perhaps teasing context. This lines up with the guidelines' note that such emojis translate to something joyful or light-hearted. There doesn't seem to be any undercurrent of fear, anger, sadness, or surprise here, given the light tone of the overall sentence structure. So, based on repeated usage and context, :v is strongly tied to 'joy' in this passage.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: "teu cape lulumpatan wae"
# - Analysis: Hmm... this part means "not tired of running around" in English. Breaking this down, "teu cape" means "not tired," and "lulumpatan" means "running around." This could be metaphorical or literal, but given the informal and humorous tone set by ":v," it seems more metaphorical—perhaps referring to someone always being active or busy. This expression doesn't seem to explicitly convey strong emotions like anger, sadness, fear, or surprise. It's more of a comment on someone's behavior or energy level. The words themselves don't suggest joy directly either, but within the given playful context punctuated by ":v," it might hint at an amused observation about someone's energetic nature. Yet, without the emoji, it lacks direct linkage to any specific emotion.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: "kumaha weh ngagawe keun jelma mah"
# - Analysis: This translates to "whatever/just let people do" in English. It suggests a relaxed or hands-off attitude towards how others behave or work. This phrase seems to indicate a nonchalant or potentially resigned acceptance. It's like acknowledging that people will act according to their nature, regardless of interventions or suggestions. It doesn't inherently express primary emotions like joy, anger, sadness, surprise, or fear but suggests a level of indifference or relaxed acceptance. In combination with other parts of the text and the playful emojis, it indirectly supports 'joy' by maintaining a humorous, not-serious take on human behavior.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hmmm teu tiasa berkata² deui , sedih pmi di dangukeun lirikna , Komo bari ningal klip na duh deg pisan kana hate na teh
#
# # KEYWORDS
# <keyword>
# - Keyword: sedih
# - Analysis: The keyword "sedih" translates to "sad" in English. This word is directly used to describe the emotional state prompted by listening to the lyrics of a song. Since "sedih" is explicitly used, it clearly indicates the emotion of sadness as the listener felt emotional distress or unhappiness due to the music. According to the guidelines, when a word like "sedih" is used, it directly correlates to the emotion of sadness, without needing further exploration. However, pushing the boundaries of understanding, sadness could emanate from various elements such as longing, loss, or simply the melancholic melody or words resonating with personal experiences. If we reflect on how people commonly experience sadness when engaged with music, it might be the poignant message or memories triggered by the song that draws out these feelings. Hence, the presence of "sedih" here is strong evidence of sadness. Considering how this fits within the framework of emotions conveyed through language and text, "sadness" remains a fitting label to ascribe to this segment of the text.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: deg pisan kana hate
# - Analysis: The phrase "deg pisan kana hate" translates to a strong emotional impact felt in the heart in English. "Deg" could imply a heart-stopping or startling sensation, often associated with something deeply moving or shocking. When combined with "kana hate" (in the heart), it suggests a strong, visceral reaction. This expression is typically used to describe an intense feeling that can be linked to a surprise or emotional overwhelm. Returning to the guidelines, while "shock" or being emotionally moved might suggest surprise, it's more often associated with heartfelt emotion, in this case, likely linked to the sadness already mentioned. Since the text describes the listener's emotional reaction to a song and its clip, it's fair to consider both surprise and sadness. Surprising elements might be emotionally charged visuals or unexpected twists in the song's narrative, affecting the listener deeply. This phrase, therefore, conveys a profound, possibly jarring emotional experience, acting as a bridge between sadness and surprise. Thus, in this specific context, we can conclude that both sadness and surprise are plausible emotions communicated.
# - Emotions: surprise, sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness', 'surprise']
#
# # TRUE EMOTIONS
# fear, sadness
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nyeri kulit beteung pas ningali nu nga goreng,
#
# # KEYWORDS
# <keyword>
# - Keyword: beteung
# - Analysis: The Sundanese word "beteung" translates to "stomach" in English. However, in different contexts, the word could be associated with a stomachache or discomfort. In this sentence, "beteung" is used alongside "nyeri kulit," which means "skin pain." This gives a sense of physical discomfort or annoyance, possibly bordering on mild inconvenience. Since it is related to a physical sensation, it might hint at discomfort rather than an emotional reaction, but the context of physical discomfort can also suggest an undercurrent of frustration. This doesn't link directly to any specific emotion label provided, but it is important to consider the emotional context of discomfort or annoyance. Based on these elements, an underlying sense of discomfort and slight irritation might imply there's some level of mild "anger" or "irritation" involved here.
# - Emotions: anger
# </keyword>
#
# <keyword>
# - Keyword: nga goreng
# - Analysis: The phrase "nga goreng" needs to be evaluated further. "Ngagoreng" is the Sundanese term for "frying" in English, which refers to the act of cooking something by frying. From the context provided, "nga goreng" seems to be an action taking place, probably contributing to the physical discomfort or irritation mentioned initially associated with "nyeri kulit" (skin pain). The perception of someone frying may not directly contribute to any specific emotional response on its own unless there is a particular condition or connection of frying to previous experiences that causes discomfort or irritation resulting in frustration or anger. It is crucial to take a second look and notice if this action triggers a broader response or experience. Therefore, the connection between skin pain and noticing someone frying indicates displeasure, which aligns with mild "anger." So, while "nga goreng" may not be conventionally associated with a particular emotion directly, in the context of shared experiences of discomfort, it could imply mild "anger."
# - Emotions: anger
# </keyword>
#
# # PREDICTED EMOTIONS
# ['anger']
#
# # TRUE EMOTIONS
# anger, disgust, surprise
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Ulah kitu atuh mang, komen kritik ieu teh kudu ditarima lain dibales hate kitu. Goreng ka mamang nageh ke loba nu te resep. Sing bageur ka penonton teh atuh. Minimal ulah nyieun tersinggung.
#
# # KEYWORDS
# <keyword>
# - Keyword: kritik kudu ditarima
# - Analysis: The phrase "kritik kudu ditarima" translates to "criticism should be accepted" in English. In this context, it suggests a call for openness and willingness to accept feedback or criticism instead of reacting negatively. This statement implies a sense of understanding and responsibility, urging the person to embrace criticisms constructively rather than with hostility. The context does not indicate a direct emotion like joy or sadness, but it does hint at a situation that may have previously involved anger or defensiveness if criticism was not well-received. Overall, this keyword suggests an underlying tension or potential conflict that needs resolution, leaning more towards emotions like disappointment or calm acceptance rather than active negative emotions like anger.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: lain dibales hate
# - Analysis: The phrase "lain dibales hate" means "not answered with hate" in English. It directly addresses the issue of responding to criticism or certain situations with hatred or angry emotions. From this, we can infer that there is an underlying issue of anger or resentment that has been observed or experienced. This keyword indicates a disapproval of negative, hostile reactions and implies that there are feelings of anger that need to be managed or redirected. This aligns with emotions like anger, directly mentioned in opposition, showing its presence in the context even if the speaker is advocating for not using it. Thus, this keyword suggests the presence of anger that should be mitigated.
# - Emotions: anger
# </keyword>
#
# <keyword>
# - Keyword: goreng ka mamang
# - Analysis: "Goreng ka mamang" can be translated as "bad to uncle" in English. This phrase suggests that the behavior or response of the person being addressed is seen as undesirable or improper by the speaker, particularly towards someone referred to as "mamang" (uncle). The word "goreng" meaning "bad" signals disapproval or dissatisfaction, which could indicate emotions like disappointment or displeasure. It hints at the presence of discontent either towards the person being addressed or towards their actions. This dissatisfaction could be steeped in sadness or mild anger for actions perceived as disrespectful. The keyword suggests disapproval, leaning toward emotions such as anger and sadness, depending on the intensity of the situation.
# - Emotions: anger, sadness
# </keyword>
#
# <keyword>
# - Keyword: sing bageur ka penonton
# - Analysis: "Sing bageur ka penonton" translates to "be kind to the audience" in English. This phrase is a suggestion or advice to treat the audience with kindness and respect. It reflects a desire for positive interaction and goodwill between the subject and their audience. While there is no explicit emotion of joy expressed, the call for kindness reflects a hopeful or positive intent for better engagement with others. This could suggest an underlying issue where the current interaction falls short of "bageur" or kindness, possibly due to existing friction or tension. The emphasis on kindness reveals a hopeful emotion aiming for harmony, contrasting any negative emotions present in the situation, such as anger or tension, thus leaning towards positive emotions like joy or satisfaction when the suggestion is followed.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: ulah nyieun tersinggung
# - Analysis: "Ulah nyieun tersinggung" translates to "don't cause offense" in English. This phrase suggests a concern about hurting others' feelings or causing misinterpretation through one’s actions or words. It implies a situation where there may already have been instances of people feeling offended, hinting at an existing tension or unease. This keyword contains an undercurrent of anxiety about social interactions and emphasizes the importance of sensitivity and careful communication. The emphasis on not causing offense suggests a desire to avoid negative outcomes or emotions, such as sadness or anger, in social contexts. Therefore, this keyword highlights the avoidance of a negative emotional response and indicates care or concern for others’ feelings.
# - Emotions: fear, sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness', 'anger', 'joy', 'fear']
#
# # TRUE EMOTIONS
# anger, disgust
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Zodiak urang neptunus, ning teu dijelaskeun :(
#
# # KEYWORDS
# <keyword>
# - Keyword: ":("
# - Analysis: The text includes the emoticon ":(", which is commonly used to express feelings of sadness or disappointment. In many digital communications, emoticons are shortcuts to convey emotions quickly without having to spell them out. In this case, the emoticon ":(" represents a frowning face, which is universally understood as a symbol of negative emotions like unhappiness or dissatisfaction. The context around the emoticon is also important. The text speaks about "Zodiak urang neptunus, ning teu dijelaskeun," which means "Our zodiac is Neptune, but it’s not explained." This statement suggests a situation where the speaker was expecting an explanation or more information about their zodiac sign, but they did not receive it. This lack of information or unmet expectation can naturally lead to feelings of disappointment or sadness. According to the guidelines and the common understanding of emoticons, the use of ":(" in this context emphasizes the emotion of sadness.
# - Emotions: sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# joy, sadness
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Teuing ku naon kabeh lagu nu di nyanyikeun neng bintan urng resep kabeh, eta sora d jampean d dukun mana neng, 🤣🤣🤣
#
# # KEYWORDS
# <keyword>
# - Keyword: 🤣🤣🤣
# - Analysis: Let me start by focusing on the laughing emojis "🤣🤣🤣". This emoji is typically used to express extreme laughter, often due to something being very funny or amusing. In this context, the person is clearly amused by the situation, potentially because of the playful and humorous nature of the comment about the singer's voice being so enchanting that it seems magically influenced by a shaman. The choice of laughing emojis indicates that the speaker is not being serious and finds the idea amusing or light-hearted. According to the guidelines, laughter-like expressions, such as these emojis, typically indicate `joy`. The presence of these emojis reinforces the idea that the text is meant to convey a sense of enjoyment and humor rather than anything negative.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: eta sora d jampean d dukun
# - Analysis: Now, let's consider the phrase "eta sora d jampean d dukun," which translates to "that voice is enchanted by a shaman." This phrase is central to understanding the emotion in the text. The speaker uses hyperbole to describe the singer's voice as so powerful or captivating that it seems almost magical. This could be interpreted as both admiration and humor. Admiration because describing something as "enchanted" elevates its quality to a magical level, suggesting the speaker is impressed. However, the humor comes from the exaggeration and the absurdity of the claim that a shaman would be involved in enchanting a singing voice. Although there is an element of sarcasm, the presence of laughing emojis confirms that the tone remains lighthearted and joyful rather than mocking or critical. There is no guideline indicating that this specific type of sarcasm correlates with a negative emotion, so it remains aligned with the expression of amusement and enjoyment.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# tapi domba anakan namah lain ku kuring mreun. 😂 ku domba dai nyh
#
# # KEYWORDS
# <keyword>
# - Keyword: 😂
# - Analysis: Let me focus on the emoji "😂" present in the text. According to the guidelines, the emoji "😭" can indicate extreme laughter in humorous contexts, which usually corresponds to joy. Although "😂" is technically a different emoji from "😭", they are often used interchangeably to convey the same meaning – laughter to the point of tears. In this context, "😂" is indeed expressing a strong sense of humor or amusement. The text also contains some casual phrases and the overall tone is light-hearted, which aligns well with a joyful and humorous sentiment. There is nothing in the surrounding text to suggest any negative emotions such as sadness or anger; instead, it appears to be a playful or self-deprecating remark about not being responsible for a sheep. This nuance strengthens the interpretation of joy associated with the emoji "😂". So, based on what I've deduced, the presence of this emoji strongly supports the emotion of joy in the text.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lebaran Taun ayeuna bisa karumpul jeung klwrga moal nya mang. ? Aya korona ayna mah euy jdi sedih 😭😭😭😭
#
# # KEYWORDS
# <keyword>
# - Keyword: sedih
# - Analysis: The keyword "sedih" translates to "sad" in English. This word explicitly conveys the emotion of sadness. When someone says they are "sedih," it implies they are experiencing a feeling of sorrow or unhappiness. In this context, the speaker is expressing their sadness about not being able to gather with family during Lebaran, which is usually a joyful time for family reunions. The cause of this sadness is further contextualized by the mention of "korona," indicating the COVID-19 pandemic is preventing the usual family gathering. The presence of the pandemic has disrupted normal traditions and celebrations, leading to this emotional response. Therefore, it is clear that the primary emotion conveyed by the word "sedih" in this context is sadness.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: 😭😭😭😭
# - Analysis: The multiple crying face emojis "😭" can represent intense emotions. According to the guidelines, although the crying emoji does not always indicate sadness, in this context, it aligns with the verbal expression of "sedih." The use of multiple crying emojis suggests an amplification of the sadness felt. The context involves reflecting on the inability to gather with family due to the COVID-19 pandemic, a situation that naturally evokes sadness, especially during a culturally significant event like Lebaran. The intention here is likely to highlight the depth of the speaker's emotional distress rather than to convey joy or humor. Therefore, the predominant emotion expressed by these crying emojis, in this scenario, aligns with sadness, complementing the previously identified emotion.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: klwrga moal nya
# - Analysis: The phrase "klwrga moal nya" suggests a concern or doubt about not being able to meet with family. "Klwrga" means "family," and "moal" translates to "won't" or "not." The context surrounding this is the mention of "korona," pointing to a possible reason for not being able to gather. The speaker appears to express a sense of uncertainty and disappointment. Uncertainty can often lead to feelings of fear or anxiety, while disappointment is closely related to sadness. However, given the overall context of the message where sadness is already the predominant emotion conveyed through both the explicit use of "sedih" and the crying emojis, this keyword further supports the feeling of sadness rather than introducing an entirely new emotion. The potential anticipation of not meeting with family, coupled with the ongoing pandemic, reinforces the sense of sorrow.
# - Emotions: sadness
# </keyword>
#
# <keyword>
# - Keyword: Lebaran Taun ayeuna bisa karumpul
# - Analysis: "Lebaran Taun ayeuna bisa karumpul" translates to "This year's Lebaran can gather." This part of the text highlights the traditional expectation of gathering during Lebaran. The mention of Lebaran here signifies an important cultural and familial event that is typically associated with joy and celebration. However, the surrounding context introduces doubt about the possibility of this gathering, shifting the expectation towards disappointment or sadness rather than joy. The anticipated inability to meet with family due to COVID-19 transforms the usual celebration into a source of reflection and longing, which are often connected with sadness. This expectation not met due to the pandemic further aligns with the dominant emotion in the text, amplifying the sentiment of loss and sadness rather than evoking the traditional joy associated with Lebaran.
# - Emotions: sadness
# </keyword>
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Cisitu mana aya teu? 😂 tapi ayeuna ngalih ka parakan muncang 😂
#
# # KEYWORDS
# <keyword>
# - Keyword: 😂
# - Analysis: The text contains two instances of the emoji 😂, which is commonly interpreted as a sign of laughter or joking. Based on the guidelines, this emoji often signifies joy because laughter generally reflects a positive and joyous emotion. Given the context, the speaker is mentioning "Cisitu" and "parakan muncang" which appear to be places, and the use of 😂 suggests they are making light of the situation, probably indicating a humorous or lighthearted remark about moving from one place to another. There is no indication of negative emotions like anger, fear, or sadness, as nothing in the text suggests any distress or discomfort. The primary focus is on the humor and joy derived from the situation, as underlined by the multiple laughter emojis. Recalling the guideline about 😂 being tied to joy, we can confidently associate a joyful emotion with this text. However, if there’s an implied meaning in the conversation that we aren’t privy to, the presence of multiple laughter emojis still overwhelmingly suggests the primary emotion is joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mantap neng geulis bikin lagu na teu aya anu nurutan debes gaduh putri kawas neng azmy kacida bungahna sebagai orangtua
#
# # KEYWORDS
# <keyword>
# - Keyword: bungah
# - Analysis: The keyword "bungah" in Sundanese translates to "happy" or "joyful" in English. This word directly communicates a sense of happiness or joy. In the context of the sentence, where someone is expressing their delight and pride in a daughter (referred to as "neng azmy"), the word "bungah" strongly conveys the emotion of joy. The sentence expresses the pride and joy of being a parent to such a talented and beautiful daughter, which naturally includes emotions of happiness and fulfillment. The term "bungah" is pivotal in expressing the overall positive and uplifting tone of this statement, strongly indicating the presence of joy.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: geulis
# - Analysis: The keyword "geulis" translates to "beautiful" in English. While this word itself does not directly convey a strong emotion, it often carries positive connotations. In the context of the sentence, it adds to the overall sense of admiration and pride. When someone is described as beautiful, especially in a positive statement about a child, it often involves feelings of joy and admiration. Thus, while "geulis" itself might not express a distinct emotion, its association with positive traits contributes to the broader context of joyfulness and positive emotions.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: kacida
# - Analysis: The keyword "kacida" translates to "very" or "extremely" in English. This word serves as an intensifier in the sentence, emphasizing the degree of the feeling being expressed. In this statement, it is used to underscore the level of "bungah" (joy) the speaker feels. Intensifiers like "kacida" play a significant role in emphasizing the strength of an emotion, and here, it highlights an extreme sense of joy and pride as a parent. The use of such an intensity marker shows that the feelings of joy are profound and deeply felt, which aligns with the overall expression of happiness in the text.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Geunaheun lah jang joget wkwk meski aink teu ngarti
#
# # KEYWORDS
# <keyword>
# - Keyword: wkwk
# - Analysis: The keyword "wkwk" is a text-based representation of laughter, similar to "hahaha" in English. When people use "wkwk," it typically signifies amusement or laughter, conveying a cheerful and joyful tone. Based on the provided guidelines, laughter-like expressions such as "wkwkw" usually indicate the emotion of joy. In this context, the sentence mentions "Geunaheun lah jang joget," which implies some form of excusable or humorous situation regarding dancing. Despite stating "meski aink teu ngarti," which means "even if I don't understand," the inclusion of "wkwk" indicates that the speaker finds humor or levity in the situation. This suggests that even though there might be confusion or a lack of understanding, the overall tone remains light-hearted and pleased. Therefore, the use of "wkwk" is a clear indicator of joy in this context, aligning with how laughter is normally associated with happiness or mirth.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kang abi mah request sanes lagu tp hoyong ningali feat kang sule salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda 🙏🙏🙏
#
# # KEYWORDS
# <keyword>
# - Keyword: hoyong ningali feat kang sule
# - Analysis: The phrase "hoyong ningali feat kang sule" translates to "want to see a feature with Kang Sule" in English. "Hoyong" means "want" or "wish," and "ningali" means "to see" or "to watch." "Feat" suggests a collaboration or feature with someone, in this case, "Kang Sule," who is a well-known Sundanese entertainer with a reputation for comedy and music. This expression indicates an interest or desire, often accompanied by eagerness. Eagerness in this context can be closely associated with anticipation and joy. Since Kang Sule is a comedian and entertainer, the anticipation is likely positive, oriented towards being entertained or enjoying his performance. Additionally, the use of the hands pressed together emoji 🙏🙏 indicates a polite request or a respectful expression, often conveying hopefulness or a sincere wish, which aligns with an emotional tone of joy and anticipation.
# - Emotions: joy
# </keyword>
#
# <keyword>
# - Keyword: salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda
# - Analysis: The phrase "salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda" translates to "one of the Sundanese artists who do not forget the Sundanese culture." This represents an appreciation and respect for cultural heritage, which can evoke pride and joy. The use of "teu hilap" meaning "do not forget," indicates a sense of loyalty and commitment to one's roots and traditions. This dedication to cultural preservation can infuse feelings of pride and joy, particularly in contexts where cultural elements are being retained and valued. There’s also an underlying sense of gratitude towards an artist who continues to honor and showcase this culture, bringing about positive emotions related to cultural pride and joy.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Rek nantangan ngadar seblak pang ladaana sakota bandung duaan jeung mang koko wkkwkw resep sigana,
#
# # KEYWORDS
# <keyword>
# - Keyword: wkkwkw
# - Analysis: The keyword "wkkwkw" represents a laughter-like expression commonly used in text to convey amusement or humor. In the context of this sentence, it suggests that the speaker finds the idea of challenging to eat the spiciest seblak in Bandung with "mang koko" to be funny and enjoyable. The guidelines indicate that such laughter-like expressions typically indicate `joy`. Given this context, "wkkwkw" clearly reflects humour or amusement, showing that the speaker is entertained by the thought of the challenge. Therefore, the emotion of joy is prominent here due to the laughter indication, and it dominates the emotional interpretation of this sentence.
# - Emotions: joy
# </keyword>
# <keyword>
# - Keyword: nantangan
# - Analysis: The word "nantangan" translates to "challenge" in English. The idea of taking on a challenge, especially one involving consuming very spicy food, can carry different emotions based on the context and the speaker's perspective. In this situation, the concept of facing a culinary challenge by eating the spiciest seblak in the city of Bandung conveys a sense of excitement and possibly some apprehension or courage, depending on the individual's confidence or experience with spicy foods. Excitement here can be linked to joy because it signifies enthusiasm about participating in an adventurous or entertaining activity. While it could potentially incorporate fear if one were imagining the heat and spice, it doesn't appear to manifest here given the humorous tone set by the laughter "wkkwkw". This laughter suggests there's more amusement and eagerness than apprehension. Therefore, based on the playful tone set within the sentence, the prevailing emotion connected to the word "nantangan" can resonate with joy.
# - Emotions: joy
# </keyword>
# <keyword>
# - Keyword: seblak pang ladaana
# - Analysis: "Seblak pang ladaana" refers to "the spiciest seblak." Seblak is a traditional Indonesian dish, and here the focus on its spiciness adds a particular intensity to the activity of eating it. The emphasis on the spiciest level suggests a particular thrill or daringness associated with consuming it, which could evoke mixed emotions. Spicy food can induce physical reactions that are intense, and people often derive pleasure from such challenges, equating it with a test of endurance or bravery. However, within the context given, considering the laughter with "wkkwkw," the text leans more toward viewing this spicy encounter as an enjoyable adventure. Instead of fear or trepidation, the laughter diminishes those elements by setting a stage for fun and daring pleasure. The vividness of "the spiciest" highlights this joy found in undertaking a foodie adventure.
# - Emotions: joy
# </keyword>
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# Evaluation:
# {'f1_macro': 0.5017281105990784, 'f1_micro': 0.7272727272727273, 'f1_label_anger': 1.0, 'f1_label_disgust': 0.0, 'f1_label_fear': 0.0, 'f1_label_joy': 0.9032258064516129, 'f1_label_sadness': 0.8571428571428571, 'f1_label_surprise': 0.25}
#
# ================================================================================================================================
# PROMPT PATH: prompts/prompts_with_keywords.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# mang dana nuhun tos ngawaler komentar abdi . Semakin ngefans 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥 . Siap mang sami-sami , salam cianjur 😊
#
# # KEYWORDS
# - ngefans -> joy (expressing admiration or fandom)
# - 😊 -> joy (smile emoji)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kur aya jang ongkos ngan eweuh jang dahar :((
#
# # KEYWORDS
# - eweuh jang dahar -> sadness (lack of money for food can lead to distress)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Aduh Naha saya Karak nyaho Chanel iyeu, katinggaleun euyyy, tapi mantap lah
#
# # KEYWORDS
# - aduh -> surprise (expresses a reaction to new information)
# - karak nyaho -> surprise (realizing something for the first time)
# - katinggaleun euyyy -> sadness (expressing feeling of missing out)
# - mantap -> joy (expresses satisfaction or being impressed)
#
# # PREDICTED EMOTIONS
# ['surprise', 'sadness', 'joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Sunda na timana ieu teh mang?
#
# # KEYWORDS
# - mang? -> surprise (expression of curiosity or seeking information)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hayam naon anu sagala dina suku
#
# # KEYWORDS
# - sagala dina suku -> surprise (it is unusual or unexpected for something to be completely on the leg).
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang urang subscribers maneh tapi urang ngadukung persija tapi.teu nanaonlah nu penting urang resep vidio nu di upload ku maneh. #VIKJAK.
#
# # KEYWORDS
# - ngadukung persija -> joy (positive feeling toward the team)
# - resep vidio nu di upload ku maneh -> joy (enjoyment and satisfaction with the videos)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Uing teu di ajak mang :(
#
# # KEYWORDS
# - teu di ajak -> sadness (feeling left out or not included)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kang abi mah request sanes lagu tp hoyong ningali feat kang sule salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda 🙏🙏🙏
#
# # KEYWORDS
# - hoyong ningali feat -> joy (expressing a wish to see a collaboration)
# - nu teu hilap ka kabudayaan sunda -> joy (appreciation for someone not forgetting Sundanese culture)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# bae keun mang kan aya khasna masing2
#
# # KEYWORDS
# - masing2 -> acceptance (implies tolerance or acceptance of differences)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Asa nalangsa Ieu abdi , sedih ih
#
# # KEYWORDS
# - nalangsa -> sadness (expressing feeling of being down or gloomy)
# - sedih -> sadness (directly translates to sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# fear, sadness
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hartunuhun neng Azmy z nya, Enakeun pisan euy, Jaga urang cobakeun ieu mah sukses terussss,
#
# # KEYWORDS
# - Enakeun pisan euy -> joy (indicates something is enjoyable)
# - sukses terussss -> joy (indicates a positive outcome or achievement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang fiksi urang ti garut Urang bungah pisan ngadangu na ge euy Bener pisan lagu teh ngamumule basa sunda teh mun teu ku urang ku saha deui Mun lain ti urang ti saha deui Sehat mang fiksi💪💪
#
# # KEYWORDS
# - bungah -> joy (expression of joy at hearing something)
# - ngamumule basa sunda -> joy (pride and happiness about preserving the Sundanese language)
# - sehat -> joy (positive well-wishing for health)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Galgadot na parahyangann ieu mh 😂😂😂
#
# # KEYWORDS
# - 😂😂😂 -> joy (laughter-like expression)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# alhamdulillah hatur nuhun otw nonton ieu mah
#
# # KEYWORDS
# - alhamdulillah -> joy (expression of gratitude)
# - hatur nuhun -> joy (expression of thanks)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lin kadua atoh heu jadi buming deui ku 3 pemuda berbahaya lagu ieu th
#
# # KEYWORDS
# - atoh -> joy (expresses excitement)
# - buming -> joy (indicates popularity and excitement)
# - berbahaya -> fear (indicates something might be harmful or risky)
#
# # PREDICTED EMOTIONS
# ['joy', 'fear']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# ngajieun video adi kaka lieur deui atuh mang. kangeun
#
# # KEYWORDS
# - "lieur" -> sadness (expressing confusion or mental distress)
# - "kangeun" -> sadness (indicating longing or missing someone)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hadir ah bisi pajar keun lain urang Sunda 🤣🤣
#
# # KEYWORDS
# - 🤣 -> joy (laughter-like emoji indicates amusement)
# - Hadir -> surprise (expressing attendance or presence in a possibly unexpected way)
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
#
# # KEYWORDS
# - ":v" (laughter-like expression) -> joy (indicates amusement or light-heartedness)
# - "teu cape lulumpatan wae" (not tired of running around) -> surprise (implies unexpected endurance or energy)
# - "kumaha weh ngagawe keun jelma" (however people make it work) -> surprise (suggests unpredictability or adaptability of people)
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Sumpah, ti kabeh lagu nu di cover menurut sayah pribadi ieu nu paling enakeun, 👍👍👍 Hadeeeee
#
# # KEYWORDS
# - enakeun -> joy (positive appreciation)
# - 👍👍👍 -> joy (positive approval)
# - Hadeeeee -> joy (expression of praise)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Curiga dekah anu make kacamata si Asep
#
# # KEYWORDS
# - Curiga -> fear (suggests suspicion or concern)
#
# # PREDICTED EMOTIONS
# ['fear']
#
# # TRUE EMOTIONS
# surprise
#
# Evaluation:
# {'f1_macro': 0.7271524771524772, 'f1_micro': 0.7843137254901961, 'f1_label_anger': 1.0, 'f1_label_disgust': 1.0, 'f1_label_fear': 0.0, 'f1_label_joy': 0.9285714285714286, 'f1_label_sadness': 0.8888888888888888, 'f1_label_surprise': 0.5454545454545454}

# %%
prompt_evaluations
# Out:
# [{'prompts/prompt_with_keywords_and_analysis.txt': {'f1_macro': 0.5017281105990784,
#    'f1_micro': 0.7272727272727273,
#    'f1_label_anger': 1.0,
#    'f1_label_disgust': 0.0,
#    'f1_label_fear': 0.0,
#    'f1_label_joy': 0.9032258064516129,
#    'f1_label_sadness': 0.8571428571428571,
#    'f1_label_surprise': 0.25}},
#  {'prompts/prompts_with_keywords.txt': {'f1_macro': 0.7271524771524772,
#    'f1_micro': 0.7843137254901961,
#    'f1_label_anger': 1.0,
#    'f1_label_disgust': 1.0,
#    'f1_label_fear': 0.0,
#    'f1_label_joy': 0.9285714285714286,
#    'f1_label_sadness': 0.8888888888888888,
#    'f1_label_surprise': 0.5454545454545454}}]

# %% [markdown]
# ## Save Evaluation

# %%
# save_df = df.copy()
# save_df[emotion_cols] = y_pred
# save_df.to_csv('eval_sun.csv', index=False)
# print("Saved to: eval_sun.csv")
