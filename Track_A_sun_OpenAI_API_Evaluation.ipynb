# %% [markdown]
# # Libraries

# %%
import os
import json
import re
import pandas as pd
from datetime import datetime
from openai import OpenAI
from sklearn.metrics import f1_score
# from pprint import pprint

pd.set_option('max_colwidth', None)

# %% [markdown]
# # Config

# %%
seed = 42
client = OpenAI(api_key=json.load(open('secrets.json'))['OPENAPI_SECRET_KEY'])
idn2eng_emotion_map = {
    'marah': 'anger',
    'jijik': 'disgust',
    'takut': 'fear',
    'senang': 'joy',
    'sedih': 'sadness',
    'terkejut': 'surprise',
    'biasa': 'neutral',
}
prompt_paths = [
    # 'prompts/prompt_with_keywords_and_analysis.txt',
    'prompts/prompt_with_keywords.txt',
    'prompts/prompt_with_keywords_v3.txt',
    # 'prompts/prompt_with_keywords_and_intensity.txt',
    # 'prompts/prompt_with_keywords_v2.txt',
    # 'prompts/prompt_with_keywords_without_guidelines.txt'
]
prompt_evaluations_dir = 'prompt_evaluations'

# %% [markdown]
# # Data

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/preprocessed_data/track_a/sun_70_15_15_stratify_v2/val.csv')
df = df.rename(columns=idn2eng_emotion_map) # Translate emotion columns from Indonesian to English

print("DF size:", len(df))
df.head()
# Out:
# DF size: 128
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                    emotion  anger  disgust  fear  joy  sadness  surprise  \
# 0                   senang      0        0     0    1        0         0
# 1                   senang      0        0     0    1        0         0
# 2         senang, terkejut      0        0     0    1        0         1
# 3         senang, terkejut      0        0     0    1        0         1
# 4  senang, sedih, terkejut      0        0     0    1        1         1
#
#    neutral
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Remove data with 'neutral' emotion and the 'neutral' column
if 'neutral' in df.columns:
    df = df[~(df['neutral'] == 1)]  
    df = df.drop('neutral', axis=1) 

# Store emotion columns
emotion_cols = [col for col in df.columns if col not in ['Unnamed: 0', 'text', 'emotion', 'id']]
df['emotion'] = df.apply(lambda row: ', '.join([emotion for emotion in emotion_cols if row[emotion] == 1]), axis=1)

print("DF size (after removing emotion 'neutral'):", len(df))
print("Emotion columns:", emotion_cols)
df.head()
# Out:
# DF size (after removing emotion 'neutral'): 121
# Emotion columns: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
#                                                                                            text  \
# 0                                                  alhamdulillah hatur nuhun otw nonton ieu mah
# 1                                                                Nongton iklan nepi ka tamat ,😭
# 2  min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
# 3                        Hebaaat , mang mung basa sundana rada rapihken ulah babeulit, nya, nya
# 4      Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
#                   emotion  anger  disgust  fear  joy  sadness  surprise
# 0                     joy      0        0     0    1        0         0
# 1                     joy      0        0     0    1        0         0
# 2           joy, surprise      0        0     0    1        0         1
# 3           joy, surprise      0        0     0    1        0         1
# 4  joy, sadness, surprise      0        0     0    1        1         1

# %% [markdown]
# # Evaluation

# %%
def get_prompt(prompt_path):
    prompt = None
    with open(prompt_path, 'r') as f:
        prompt = f.read()
    return prompt

def one_hot_encode_emotions(emotions, emotion_cols=emotion_cols):
    one_hot_emotion = [1 if emotion_col in emotions else 0 for emotion_col in emotion_cols]
    return one_hot_emotion

def get_pred_tag_content(prediction, tag_name):
    match = re.search(fr'<{tag_name}>(.*?)</{tag_name}>', prediction, re.DOTALL)
    tag_content = match.group(1).strip() if match else None
    return tag_content

def predict(text, prompt):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system', 'content': prompt},
            {'role': 'user', 'content': text},
        ],
        max_tokens=1000,
    )
    return completion.choices[0].message.content

prediction = predict(
    text="Cek urang mah jelema goblog teh nyaeta, jelema nu menta udud ngomong teu boga, padahal Aya sabungkus dinu pesak 😂🤣",
    prompt=get_prompt(prompt_paths[0]),
)

keywords_pred = get_pred_tag_content(prediction, 'keywords')
print("Precicted keywords and their analyses:")
print(keywords_pred)
print()

emotions_pred = get_pred_tag_content(prediction, 'emotions').lower().replace("." , "").replace(" ", "").split(",")
print("Precicted emotions:", emotions_pred, "->", one_hot_encode_emotions(emotions_pred))
# Out:
# Precicted keywords and their analyses:
# - goblog -> anger, disgust (insult towards a person)
# - 😂🤣 -> joy (laughter emojis)
#
# Precicted emotions: ['anger', 'disgust', 'joy'] -> [1, 1, 0, 1, 0, 0]

# %%
def eval_sampled(n, prompt_path):
    prompt = get_prompt(prompt_path)

    df_sampled = df.sample(n=n)
    y_true = df_sampled[emotion_cols].to_numpy()

    y_pred = []
    for i, v in enumerate(df_sampled.iterrows()):
        idx, row = v

        print("=" * 64)
        print(f"{i+1} OF {len(df_sampled)}")
        print("=" * 64)

        is_valid = True

        while True:
            print("Predicting...")        

            prediction = predict(row['text'], prompt)
            keywords_pred = get_pred_tag_content(prediction, 'keywords')
            emotions_pred = get_pred_tag_content(prediction, 'emotions').replace(" ", "").split(",")
            emotions_pred_one_hot = one_hot_encode_emotions(emotions_pred, emotion_cols)

            is_valid = bool(sum(emotions_pred_one_hot))

            if is_valid:
                break
            else:
                print("Error! Prediction:", prediction)
                print()
            
        y_pred.append(emotions_pred_one_hot)

        print()
        print("# TEXT")
        print(row['text'])
        print()
        print("# KEYWORDS")
        print(keywords_pred)
        print()
        print("# PREDICTED EMOTIONS")
        print(emotions_pred)
        print()
        print("# TRUE EMOTIONS")
        print(row['emotion'])
        print()

    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=1.0)
    f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=1.0)
    f1_labels = f1_score(y_true, y_pred, average=None, zero_division=1.0)
    f1_labels_dict = {f'f1_label_{emotion_cols[i]}': float(f1_labels[i]) for i in range(len(f1_labels))}

    return {
        'prompt_path': prompt_path,
        'n': n,
        'f1_macro': float(f1_macro),
        'f1_micro': float(f1_micro),
        **f1_labels_dict,
    }

prompt_eval = []
for prompt_path in prompt_paths:
    print("=" * 128)
    print("PROMPT PATH:", prompt_path)
    print("=" * 128)

    evaluation = eval_sampled(n=20, prompt_path=prompt_path)
    print("Evaluation:")
    print(evaluation)

    prompt_eval.append(evaluation)
    
    print()
# Out:
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Neng kunaon mundur?keur naon maju oge geus boga pamajikan, 😢
#
# # KEYWORDS
# - mundur -> sadness (indicates stepping back, possibly from a relationship or situation)
# - geus boga pamajikan -> sadness (implies a reason for stepping back is due to someone being already married)
# - 😢 -> sadness (crying emoji typically indicates sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang mantan anu di sakiti mang
#
# # KEYWORDS
# - mantan -> sadness (implies a past relationship)
# - di sakiti -> sadness (indicates experiencing pain or hurt)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lin kadua atoh heu jadi buming deui ku 3 pemuda berbahaya lagu ieu th
#
# # KEYWORDS
# - atoh -> joy (joyful expression about the event happening again or becoming famous)
# - buming -> joy (excitement or happiness about something becoming popular or a hit)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hmmm teu tiasa berkata² deui , sedih pmi di dangukeun lirikna , Komo bari ningal klip na duh deg pisan kana hate na teh
#
# # KEYWORDS
# - sedih -> sadness (the word explicitly indicates feeling sad)
# - deg pisan kana hatena -> fear (the phrase suggests a reaction that causes anxiety or fear)
#
# # PREDICTED EMOTIONS
# ['sadness', 'fear']
#
# # TRUE EMOTIONS
# fear, sadness
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# sarua ajig teu ngarti tapi sediih, sedih ku teu ngarti ajiig,
#
# # KEYWORDS
# - sediih, sedih -> sadness (expressing feelings of sadness)
# - ajig -> anger (insulting word which may express anger)
#
# # PREDICTED EMOTIONS
# ['sadness', 'anger']
#
# # TRUE EMOTIONS
# anger, sadness
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang eta lagu nu terakhirna ngenaheun mang naon judulna??😂😂
#
# # KEYWORDS
# - 😂 -> joy (laughter emoji)
# - ngenaheun -> joy (conveys enjoyment or being touched emotionally)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Ulah kitu atuh mang, komen kritik ieu teh kudu ditarima lain dibales hate kitu. Goreng ka mamang nageh ke loba nu te resep. Sing bageur ka penonton teh atuh. Minimal ulah nyieun tersinggung.
#
# # KEYWORDS
# - kritik -> sadness (suggests feedback is not being positively received)
# - dibales hate -> anger (indicates a response of anger to criticism)
# - goreng -> sadness (indicates negative behavior that might result in dislike)
# - loba nu te resep -> sadness (indicates potential loss of popularity)
# - ulah nyieun tersinggung -> sadness (indicates a desire to avoid causing offense, implying previous offense)
#
# # PREDICTED EMOTIONS
# ['sadness', 'anger']
#
# # TRUE EMOTIONS
# anger, disgust
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# 42:28 mayar zakat atawa rek sodaqoh mh mang teu kdu ngadagoan gede milik, kan ayeuna ge bisa give away samak butut2 wae mh😀
#
# # KEYWORDS
# - give away -> joy (indicates sharing and generosity)
# - samak butut2 -> joy (suggests lightheartedness about the condition of items being given)
# - 😀 -> joy (smile emoji indicating happiness or amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Unfaedah tapi dugi nyeri kulit beuteung 🤣🤣🤣
#
# # KEYWORDS
# - nyeri kulit beuteung -> joy (expresses extreme laughter to the point of physical discomfort)
# - 🤣🤣🤣 -> joy (laughing emojis)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nonton video ieu mh sllu ka hibur wae. Nu tdina sedih upmi ntos ningli video ieu mh jd bungah. Hatur nuhun ach ntos ngahibur.
#
# # KEYWORDS
# - hibur -> joy (referring to being entertained)
# - sedih -> sadness (initial feeling before watching the video)
# - bungah -> joy (feeling happy after watching the video)
# - ngahibur -> joy (referring to being entertained)
#
# # PREDICTED EMOTIONS
# ['sadness', 'joy']
#
# # TRUE EMOTIONS
# joy, sadness
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Curiga dekah anu make kacamata si Asep
#
# # KEYWORDS
# - curiga -> fear (indicates suspicion)
#
# # PREDICTED EMOTIONS
# ['fear']
#
# # TRUE EMOTIONS
# surprise
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# bae keun mang kan aya khasna masing2
#
# # KEYWORDS
# - "bae keun" -> joy (indicating acceptance or letting go with a lighthearted attitude)
# - "khasna" -> joy (recognizing and appreciating uniqueness or individual charm)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Jiiiirrr picontoeun pisan ieu mah para youtubers teh hade pisan teu pa aing aing beda jeung youtubers dilembur uing mah sarombong jeung pa aing aing ngan ka itung nu bageurna
#
# # KEYWORDS
# - picontoeun -> joy (indicates admiration and appreciation)
# - hade pisan -> joy (expresses a very positive opinion)
# - bageurna -> joy (mentions goodness or virtue)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Teh azmy. Abi nga dangukeun laguna unggal dinten teras terasan, di jalan di bumi pasti ngupingkeunna lagu teh azmy 😁😁 Sukses selalu nya teh azmy sareng ki Dalang anom ❤
#
# # KEYWORDS
# - 😁😁 -> joy (laughter emojis indicating happiness or enjoyment)
# - ❤ -> joy (heart emoji indicating love or affection)
# - Sukses selalu -> joy (expression of positive wishes and encouragement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hadir nengg., aa neng duh nyeri pisan euy d dyakeun ku awe2.,
#
# # KEYWORDS
# - nyeri -> sadness (Referring to feeling hurt or pain)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# joy, sadness
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang fiksi urang ti garut Urang bungah pisan ngadangu na ge euy Bener pisan lagu teh ngamumule basa sunda teh mun teu ku urang ku saha deui Mun lain ti urang ti saha deui Sehat mang fiksi💪💪
#
# # KEYWORDS
# - bungah -> joy (expression of happiness upon hearing something)
# - ngamumule basa sunda -> joy (pride and happiness in the preservation of Sundanese language)
# - sehat mang fiksi -> joy (expression of well-wishing for health)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Entah kunaon sapoe teu mireungkeun suara teh herlina asa linglung
#
# # KEYWORDS
# - linglung -> sadness (feeling disoriented or confused)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Kang abi mah request sanes lagu tp hoyong ningali feat kang sule salah sahiji seniman sunda nu teu hilap ka kabudayaan sunda 🙏🙏🙏
#
# # KEYWORDS
# - hoyong ningali -> joy (expressing a desire to see something enjoyable)
# - seniman sunda -> joy (appreciation for local culture and artists)
# - teu hilap ka kabudayaan sunda -> joy (appreciating and remembering local culture)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lebaran Taun ayeuna bisa karumpul jeung klwrga moal nya mang. ? Aya korona ayna mah euy jdi sedih 😭😭😭😭
#
# # KEYWORDS
# - karumpul jeung klwrga -> joy (expecting to gather with family)
# - korona -> fear (due to the pandemic)
# - sedih -> sadness (explicit mention of sadness)
# - 😭 -> sadness (crying emoji associated with sadness in this context)
#
# # PREDICTED EMOTIONS
# ['joy', 'fear', 'sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang pas mang dana nyebutkeun "tah urang inget" langsung aya iklan gojek mang, saya ge jadi kainget naha teu make gofood, 😁
#
# # KEYWORDS
# - 😁 -> joy (smile emoji indicating happiness or amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# Evaluation:
# {'prompt_path': 'prompts/prompt_with_keywords.txt', 'n': 20, 'f1_macro': 0.5596405228758169, 'f1_micro': 0.7857142857142857, 'f1_label_anger': 1.0, 'f1_label_disgust': 0.0, 'f1_label_fear': 0.5, 'f1_label_joy': 0.9166666666666666, 'f1_label_sadness': 0.9411764705882353, 'f1_label_surprise': 0.0}
#
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords_v3.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Enakeun nih lagu buat pas hajatan hhe
#
# # KEYWORDS
# - enakeun -> joy (enjoyable or pleasant)
# - hhe -> joy (laughter-like expression)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mang instrumen musik anu angklung naon namina😂
#
# # KEYWORDS
# - 😂 -> joy (the emoji indicates laughter or amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Mantap enakeun ker nyepetan anak manuk,
#
# # KEYWORDS
# - mantap -> joy (expresses satisfaction)
# - enakeun -> joy (expresses enjoyment)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Neng kunaon mundur?keur naon maju oge geus boga pamajikan, 😢
#
# # KEYWORDS
# - mundur -> sadness (indicates stepping back or retreating)
# - geus boga pamajikan -> sadness (implies disappointment or unrequited feelings)
# - 😢 -> sadness (indicates crying or sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# min ai mnh teu cape lulumpatan wae :v kumaha weh ngagawe keun jelma mah ceuk mang dana ge :v
#
# # KEYWORDS
# - :v -> joy (the use of this emoticon indicates laughter or amusement)
# - lulumpatan -> joy (suggesting lively or playful activity)
# - kumaha weh ngagawe keun jelma mah -> joy (a light-hearted or humorous approach to people working)
# - ceuk mang dana -> joy (mentioning someone's opinion in a casual or humorous manner)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lin kadua atoh heu jadi buming deui ku 3 pemuda berbahaya lagu ieu th
#
# # KEYWORDS
# - buming -> surprise (refers to something becoming popular or viral again)
# - atoh -> joy (refers to a feeling of happiness or satisfaction)
#
# # PREDICTED EMOTIONS
# ['surprise', 'joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Assalamualaikum, kang lamun bade order acuk aya di lazada teu?
#
# # KEYWORDS
# - Assalamualaikum -> joy (politeness and greeting)
# - bade order acuk -> neutral (query about availability)
# - lazada -> neutral (mention of a platform)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nya enya atuh reuneuh tiheula , Manya ngajuru tiheula 😂😂😂
#
# # KEYWORDS
# - 😂 -> joy (laughter emoji indicating amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Trending ken atuh iyeu komen alus pisan haha
#
# # KEYWORDS
# - haha -> joy (laughter-like expression indicating amusement)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Abdi bakal nyeri kalau di miduakeun ku Azmy.z
#
# # KEYWORDS
# - nyeri -> sadness (indicates feeling of being hurt)
# - miduakeun -> sadness (implies being treated as second priority, leading to sadness)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lalaki cewe mang anu di gps
#
# # KEYWORDS
# - gps -> surprise (Indicates an unexpected situation or meeting)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# teu ngarti da aing mah maneh teh ngomong naon ?
#
# # KEYWORDS
# - teu ngarti -> anger (lack of understanding)
# - da aing mah maneh teh ngomong naon -> anger (frustration with communication)
#
# # PREDICTED EMOTIONS
# ['anger']
#
# # TRUE EMOTIONS
# anger, disgust
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# mang dana nuhun tos ngawaler komentar abdi . Semakin ngefans 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥 . Siap mang sami-sami , salam cianjur 😊
#
# # KEYWORDS
# - nuhun -> joy (expression of gratitude)
# - ngefans -> joy (expression of admiration and becoming a fan)
# - 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥 -> joy (energetic and enthusiastic emojis)
# - 😊 -> joy (smile emoji indicating happiness)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# waalaikumsalam ku naha jd salam ka nenk 😅 ka mang fiksi atuh salam mah sorry brow ✌ Mang fiksi jd bala yeh komen na maaf nya 🙏
#
# # KEYWORDS
# - 😅 -> joy (indicating amusement or light-heartedness)
# - ✌ -> joy (indicating friendliness or peace)
# - 🙏 -> joy (expressing humility and politeness)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Galgadot na parahyangann ieu mh 😂😂😂
#
# # KEYWORDS
# - 😂😂😂 -> joy (laughter-like expression indicates joy)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang resep musikna ceria teu melow ngenah jang jingkrak2 hahahha
#
# # KEYWORDS
# - ceria -> joy (indicates a cheerful mood)
# - ngenah jang jingkrak2 -> joy (indicates excitement and energy for dancing)
# - hahahha -> joy (indicates laughter and happiness)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hartunuhun neng Azmy z nya, Enakeun pisan euy, Jaga urang cobakeun ieu mah sukses terussss,
#
# # KEYWORDS
# - Enakeun -> joy (shows pleasure or delight)
# - Sukses terussss -> joy (indicates continuous success, suggesting happiness)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Logat Majalengka emang khas na kitu teu heran urang mah, Bener lah meningan keneh jadi patani, da lamun aweuh patani nu beunghar maol bisa dahar heuh teu
#
# # KEYWORDS
# - teu heran -> joy (indicating acceptance or familiarity)
# - urusan tani -> sadness (indicating a tough occupation)
# - aweuh patani nu beunghar -> sadness (suggesting farmers are not wealthy)
#
# # PREDICTED EMOTIONS
# ['joy', 'sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Ngiring bangga, jabar gaduh Seniman muda tur kreatif, Resep ningal nage, Lajengkeun teras kreasina teh Azmi.
#
# # KEYWORDS
# - bangga -> joy (expresses pride)
# - resep -> joy (expresses enjoyment)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# sok pang meserkeun stabilizer na bade ?
#
# # KEYWORDS
# - pang meserkeun -> surprise (Implicit suggestion or request unexpectedly)
# - bade -> surprise (Showing expectation or unforeseen plan)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy
#
# Evaluation:
# {'prompt_path': 'prompts/prompt_with_keywords_v3.txt', 'n': 20, 'f1_macro': 0.6981566820276498, 'f1_micro': 0.8085106382978723, 'f1_label_anger': 1.0, 'f1_label_disgust': 0.0, 'f1_label_fear': 1.0, 'f1_label_joy': 0.9032258064516129, 'f1_label_sadness': 1.0, 'f1_label_surprise': 0.2857142857142857}
#
# ================================================================================================================================
# PROMPT PATH: prompts/prompt_with_keywords_and_intensity.txt
# ================================================================================================================================
# ================================================================
# 1 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# bner mang baturan mraen slot wae, nyieun lagu deui kang judulna togel
#
# # KEYWORDS
# - bener mang baturan -> joy: mid (Indicates agreement or acknowledgment in an informal and friendly manner.)
# - nyieun lagu deui -> joy: mid (Expresses a creative or productive activity, which generally conveys positive emotion.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# anger, sadness, surprise
#
# ================================================================
# 2 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Syukuran mang, Kami mah mung bisa ngadoa keun,
#
# # KEYWORDS
# - Syukuran -> joy: mid (The expression of gratitude or celebration often indicates a positive emotion such as joy.)
# - ngadoa -> joy: low (Praying or wishing well suggests a positive sentiment, aligning with joy.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# fear, joy
#
# ================================================================
# 3 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Waduh NU Ku Urang di Rasaken Kuari 😓
#
# # KEYWORDS
# - Waduh -> surprise: mid (The expression "Waduh" indicates an element of surprise or unexpectedness)
# - 😓 -> sadness: mid (The emoji 😓 generally conveys a sense of distress or sadness)
#
# # PREDICTED EMOTIONS
# ['surprise', 'sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 4 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lamun t berfaedah jang naon nyieun ath kang :(
#
# # KEYWORDS
# - t berfaedah -> sadness: mid (The phrase "t berfaedah" expresses a sense of uselessness or lack of worth, contributing to the feeling of sadness.)
# - :( -> sadness: mid (The sad face emoticon typically indicates a feeling of unhappiness or disappointment.)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 5 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# tapi domba anakan namah lain ku kuring mreun. 😂 ku domba dai nyh
#
# # KEYWORDS
# - 😂 -> joy: mid (The emoji 😂 typically indicates laughter and amusement.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 6 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lalaki cewe mang anu di gps
#
# # KEYWORDS
# - gps -> surprise: mid (The term "gps" in this context might indicate a situation that is unexpected or out of the ordinary, leading to surprise.)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 7 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang teu ngarti arti lagu na, tapi asa ngena euy kanu hate
#
# # KEYWORDS
# - ngarti -> sadness: mid (The speaker is expressing a lack of understanding, which could lead to feelings of confusion or sadness.)
# - ngena -> joy, sadness: mid (The phrase "ngena euy kanu hate" suggests that the song resonates emotionally, which can lead to feelings of joy or sadness, depending on the context.)
#
# # PREDICTED EMOTIONS
# ['sadness', 'joy']
#
# # TRUE EMOTIONS
# sadness, surprise
#
# ================================================================
# 8 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Enakeun nih lagu buat pas hajatan hhe
#
# # KEYWORDS
# - enakeun -> joy: mid (The word "enakeun" suggests something pleasant or enjoyable, indicating a sense of joy.)
# - hhe (similar to "haha") -> joy: low (The expression "hhe" is a laughter-like expression, suggesting a sense of joy or amusement.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 9 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Aya meri dina rakit Boboko wadah bakatul Lain nyeri ku panyakit Kabogoh direbut batur🤣🤣😭
#
# # KEYWORDS
# - "🤣🤣" -> joy: mid (Laughter emojis suggest amusement or finding humor in the situation.)
# - "Kabogoh direbut batur" -> sadness: mid (This phrase suggests a relationship issue, where a partner is taken by someone else, which typically evokes feelings of sadness.)
# - "😭" -> joy: mid (In this humorous context, it represents extreme laughter combined with the situation.)
#
# # PREDICTED EMOTIONS
# ['joy', 'sadness']
#
# # TRUE EMOTIONS
# joy, sadness, surprise
#
# ================================================================
# 10 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hayang ulin jeung awewe tapi awewena euweuh 😭
#
# # KEYWORDS
# - hayang ulin -> sadness: mid (The desire to play or hang out with someone, and the inability to do so, suggests a longing or unfulfilled wish.)
# - euweuh -> sadness: mid (The absence of the desired company enhances the feeling of lacking or missing something.)
# - 😭 -> sadness: mid (The crying emoji in this context suggests sadness due to unfulfilled desires.)
#
# # PREDICTED EMOTIONS
# ['sadness']
#
# # TRUE EMOTIONS
# joy, sadness
#
# ================================================================
# 11 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Hha aduh mang fiksi, Ur tadi na erek sare jadi teu tulis uy
#
# # KEYWORDS
# - Hha -> joy: low (The expression "Hha" typically indicates laughter or amusement, reflecting a light sense of joy.)
# - aduh -> surprise: low (This expression is often used to indicate surprise or a mild shock.)
# - jadi teu tulis uy -> joy: mid (The phrase suggests a humorous or light-hearted issue where the subject ended up not being able to sleep, which conveys amusement.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 12 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Absen ti bogor katingaleun vidiona Sing barokah rizkinna lah mag fiksi
#
# # KEYWORDS
# - barokah -> joy: mid (The word "barokah" implies blessings, which is associated with joy and positive feelings.)
# - rizkinna -> joy: mid (The word "rizkinna" means sustenance or fortune, typically associated with positive emotions like joy and gratitude.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 13 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Nya enya atuh reuneuh tiheula , Manya ngajuru tiheula 😂😂😂
#
# # KEYWORDS
# - 😂😂😂 -> joy: mid (The presence of laughter emojis typically indicates joy.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 14 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# "ceuk urangmah jelema goblog teh nyaeta 'jelema nu hitut sorangan Diambeuan ku sorangan'
#
# # KEYWORDS
# - goblog -> anger: mid (The term "goblog" is an insult, indicating anger towards someone's stupidity.)
# - hitut -> joy: low (The mention of a fart can be humorous, adding a low intensity of joy.)
#
# # PREDICTED EMOTIONS
# ['anger']
#
# # TRUE EMOTIONS
# anger, disgust
#
# ================================================================
# 15 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Urang resep musikna ceria teu melow ngenah jang jingkrak2 hahahha
#
# # KEYWORDS
# - ceria -> joy: mid (The word "ceria" indicates a cheerful and lively mood.)
# - jingkrak2 -> joy: mid (The action of "jingkrak-jingkrak" suggests energetic and happy movement.)
# - hahahha -> joy: mid (The laughter "hahahha" indicates amusement or joy.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 16 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Wow mang majalengka pinuh ku pepelakan nu leutik saperti bawang beureum sawah teu kawas di urang kadang sawah kadang kebon di CIAMIS
#
# # KEYWORDS
# - Wow -> surprise: low (The word "Wow" indicates a mild level of surprise or admiration.)
# - pepelakan -> joy: mid (Discussing plants and agriculture in a positive light can indicate contentment or joy.)
# - bawang beureum -> joy: mid (The mention of red onions in a productive way indicates aspects of joy related to agriculture.)
# - teu kawas di urang -> surprise: low (The phrase "not like ours" expresses a mild sense of surprise due to comparison.)
#
# # PREDICTED EMOTIONS
# ['joy', 'surprise']
#
# # TRUE EMOTIONS
# joy, sadness, surprise
#
# ================================================================
# 17 OF 20
# ================================================================
# Predicting...
# Error! Prediction: <keywords>
# - "Assalamualaikum" -> not directly associated with any predefined emotion.
# - "lamun bade order acuk" -> no strong emotion; neutral phrase about ordering clothing.
# - "aya di lazada teu?" -> no strong emotion; neutral inquiry about availability on Lazada.
# </keywords>
#
# <emotions>
# None
# </emotions>
#
# Predicting...
#
# # TEXT
# Assalamualaikum, kang lamun bade order acuk aya di lazada teu?
#
# # KEYWORDS
# - Order -> surprise: low (The text contains a query about the availability of clothes for order, showing curiosity.)
#
# # PREDICTED EMOTIONS
# ['surprise']
#
# # TRUE EMOTIONS
# joy
#
# ================================================================
# 18 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Logat Majalengka emang khas na kitu teu heran urang mah, Bener lah meningan keneh jadi patani, da lamun aweuh patani nu beunghar maol bisa dahar heuh teu
#
# # KEYWORDS
# - "emang khas" -> surprise: low (Expresses acknowledgment of uniqueness which can imply a mild surprise.)
# - "teu heran" -> none: low (Indicates lack of surprise or acceptance as normal.)
# - "bener lah" -> none: low (Expresses agreement or affirmation, not tied to a strong emotion.)
# - "mengingat" -> sadness: low (Reflective and thoughtful tone may imply some sadness, but the intensity is low.)
# - "maol bisa dahar" -> fear: mid (Expresses concern about not being able to eat without farmers, indicating fear of lack.)
#
# # PREDICTED EMOTIONS
# ['fear']
#
# # TRUE EMOTIONS
# sadness
#
# ================================================================
# 19 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lin kadua atoh heu jadi buming deui ku 3 pemuda berbahaya lagu ieu th
#
# # KEYWORDS
# - atoh -> joy: mid (The word "atoh," which means happy or delighted, indicates a sense of joy regarding the situation.)
# - buming deui -> joy: mid (The phrase "buming deui" refers to something that has become popular or trending again, which often brings excitement or joy.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy, surprise
#
# ================================================================
# 20 OF 20
# ================================================================
# Predicting...
#
# # TEXT
# Lanjutkeun Mang hade pisan lahh. Sunda Is The Best 👍
#
# # KEYWORDS
# - hade pisan -> joy: mid (The expression "hade pisan" indicates a high level of appreciation or satisfaction.)
# - Sunda Is The Best -> joy: mid (The phrase shows pride or positive sentiment towards Sunda, which expresses joy.)
# - 👍 -> joy: low (The thumbs up emoji generally indicates agreement or approval, aligning with joy.)
#
# # PREDICTED EMOTIONS
# ['joy']
#
# # TRUE EMOTIONS
# joy
#
# Evaluation:
# {'prompt_path': 'prompts/prompt_with_keywords_and_intensity.txt', 'n': 20, 'f1_macro': 0.40845204178537514, 'f1_micro': 0.6428571428571429, 'f1_label_anger': 0.6666666666666666, 'f1_label_disgust': 0.0, 'f1_label_fear': 0.0, 'f1_label_joy': 0.8148148148148148, 'f1_label_sadness': 0.7692307692307693, 'f1_label_surprise': 0.2}

# %%
prompt_eval
# Out:
# [{'prompt_path': 'prompts/prompt_with_keywords.txt',
#   'n': 20,
#   'f1_macro': 0.5596405228758169,
#   'f1_micro': 0.7857142857142857,
#   'f1_label_anger': 1.0,
#   'f1_label_disgust': 0.0,
#   'f1_label_fear': 0.5,
#   'f1_label_joy': 0.9166666666666666,
#   'f1_label_sadness': 0.9411764705882353,
#   'f1_label_surprise': 0.0},
#  {'prompt_path': 'prompts/prompt_with_keywords_v3.txt',
#   'n': 20,
#   'f1_macro': 0.6981566820276498,
#   'f1_micro': 0.8085106382978723,
#   'f1_label_anger': 1.0,
#   'f1_label_disgust': 0.0,
#   'f1_label_fear': 1.0,
#   'f1_label_joy': 0.9032258064516129,
#   'f1_label_sadness': 1.0,
#   'f1_label_surprise': 0.2857142857142857},
#  {'prompt_path': 'prompts/prompt_with_keywords_and_intensity.txt',
#   'n': 20,
#   'f1_macro': 0.40845204178537514,
#   'f1_micro': 0.6428571428571429,
#   'f1_label_anger': 0.6666666666666666,
#   'f1_label_disgust': 0.0,
#   'f1_label_fear': 0.0,
#   'f1_label_joy': 0.8148148148148148,
#   'f1_label_sadness': 0.7692307692307693,
#   'f1_label_surprise': 0.2}]

# %% [markdown]
# ## Save Evaluation

# %%
with open(os.path.join(prompt_evaluations_dir, f'prompt_eval_{datetime.now().strftime("%Y%m%d%H%M%S")}.json'), 'w') as f:
    json.dump(prompt_eval, f, indent=4)

# %% [markdown]
# ## View Saved Evaluations

# %%
prompt_eval_names = os.listdir(prompt_evaluations_dir)
prompt_eval_dfs = [pd.read_json(os.path.join(prompt_evaluations_dir, prompt_eval_name)) for prompt_eval_name in prompt_eval_names]

concat_df = pd.concat(prompt_eval_dfs).groupby('prompt_path', as_index=False)
mean_df = concat_df.mean()
sum_df = concat_df.sum()
mean_df['n'] = sum_df['n']
mean_df
# Out:
#                                            prompt_path    n  f1_macro  \
# 0                     prompts/prompt_with_keywords.txt  280  0.564517
# 1        prompts/prompt_with_keywords_and_analysis.txt   60  0.517154
# 2       prompts/prompt_with_keywords_and_intensity.txt   40  0.437113
# 3                  prompts/prompt_with_keywords_v2.txt  120  0.541275
# 4                  prompts/prompt_with_keywords_v3.txt   80  0.544549
# 5  prompts/prompt_with_keywords_without_guidelines.txt   40  0.517654
#
#    f1_micro  f1_label_anger  f1_label_disgust  f1_label_fear  f1_label_joy  \
# 0  0.754588        0.640476          0.571429       0.178571      0.915101
# 1  0.706220        0.500000          0.666667       0.000000      0.851478
# 2  0.704407        0.333333          0.500000       0.000000      0.876157
# 3  0.740009        0.388889          0.666667       0.166667      0.872351
# 4  0.701911        0.914286          0.166667       0.250000      0.854973
# 5  0.667641        0.250000          1.000000       0.000000      0.873016
#
#    f1_label_sadness  f1_label_surprise
# 0          0.850094           0.231432
# 1          0.779221           0.305556
# 2          0.813187           0.100000
# 3          0.874038           0.279040
# 4          0.830556           0.250812
# 5          0.717949           0.264957
